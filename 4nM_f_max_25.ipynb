# %%
import numpy as np
import matplotlib.pyplot as plt
from files_sorting import Txt_Reading
import pandas as pd
import os

# %matplotlib inline

# %%
folder = "4nM"
f_MAX = [10, 15, 20, 25, 30, 35]
f_max = 25
reading = Txt_Reading(folder, f_max)

# %%
file = reading.readTxt(number=9, N=1, ty='f', graph=True)

# %%
reading.params_df
# Out:
#    f_rupture  f_rupture_next    x_ssDNA  N_nucleotides     t_0       λ_0  \
# 0      4.284          3.2089  34.632756     112.831508  0.6836  0.117511
#
#       a_pre    b_pre     a_post    b_post
# 0  19.98869  1.56872  31.814645 -1.125242

# %%
# plt.plot(reading.λ[:600], reading.force_Y[:600])
# plt.scatter(reading.λ_0, reading.f_rupture, marker="^", c="red")
# plt.scatter(reading.λ[(reading.index+1)[0]], reading.f_rupture_next, marker="v", c="orange", s=1000);

# %%
reading.f_rupture, reading.f_rupture_next
# Out:
# ([4.284], [3.2089])

# %%
file = reading.readTxt(number=9, N=7, ty='f', graph=True)
reading.params_df
# Out:
#    f_rupture  f_rupture_next    x_ssDNA  N_nucleotides      t_0       λ_0  \
# 0     3.1392          2.4125  32.466536     124.071613  0.37793  0.076462
#
#        a_pre     b_pre     a_post    b_post
# 0  11.739145  1.701838  25.338621  0.038979

# %%
# Columns: CycleCount, X_force,	Y_force, Z_force, time(sec), Status, λ

# %%
molecules, all_molecules_f, all_molecules_u = reading.sequential_analysis()
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Not saving file Data/4nM/25/9/1_f.txt
# Not saving file Data/4nM/25/9/3_f.txt
# Not saving file Data/4nM/25/9/7_f.txt
# Not saving file Data/4nM/25/9/11_f.txt
# Not saving file Data/4nM/25/9/19_f.txt
# Not saving file Data/4nM/25/9/21_f.txt
# Not saving file Data/4nM/25/9/23_f.txt
# Not saving file Data/4nM/25/9/1_u.txt
# Not saving file Data/4nM/25/9/4_u.txt
# Not saving file Data/4nM/25/9/16_u.txt
# Not saving file Data/4nM/25/9/25_u.txt
# Not saving file Data/4nM/25/9/32_u.txt
# Not saving file Data/4nM/25/10/1_f.txt
# Not saving file Data/4nM/25/10/5_f.txt
# Not saving file Data/4nM/25/10/1_u.txt
# Not saving file Data/4nM/25/15/5_f.txt
# Not saving file Data/4nM/25/15/7_f.txt
# Not saving file Data/4nM/25/15/10_f.txt
# Not saving file Data/4nM/25/15/7_u.txt
# Not saving file Data/4nM/25/15/8_u.txt
# Not saving file Data/4nM/25/15/23_u.txt
# Not saving file Data/4nM/25/20/2_f.txt
# Not saving file Data/4nM/25/20/5_f.txt
# Not saving file Data/4nM/25/20/7_f.txt
# Not saving file Data/4nM/25/20/9_f.txt
# Not saving file Data/4nM/25/20/10_f.txt
# Not saving file Data/4nM/25/20/20_f.txt
# Not saving file Data/4nM/25/20/21_f.txt
# Not saving file Data/4nM/25/20/22_f.txt
# Not saving file Data/4nM/25/20/1_u.txt
# Not saving file Data/4nM/25/20/2_u.txt
# Not saving file Data/4nM/25/20/22_u.txt
# Not saving file Data/4nM/25/20/23_u.txt
# Not saving file Data/4nM/25/21/7_f.txt
# Not saving file Data/4nM/25/21/1_u.txt
# Not saving file Data/4nM/25/21/8_u.txt
# Saving results...

# %%
λ = reading.file[1:, -1]
force_Y = np.abs(reading.file[1:, 2])

# %%
file = reading.readTxt(number=9, N=25, ty='u', graph=True)

# %%
reading.params_df
# Out:
#    f_rupture  f_rupture_next    x_ssDNA  N_nucleotides      t_0       λ_0  \
# 0     3.7863           2.824  36.004237     124.468397  0.49804  0.082369
#
#        a_pre     b_pre     a_post    b_post
# 0  13.715527  1.807963  25.025495  0.325012

# %%
reading.k_eff
# Out:
# 0.027504696033458093

# %%
reading.res_fold.head()
# Out:
#    Molecule       f  f_next    x_ssDNA  N_nucleotides      t_0
# 0       9.0  4.6125  4.4732   5.209108      16.420064  0.71093
# 1       9.0  1.9479  1.1847   2.820699      14.688716  0.02246
# 2       9.0  4.4367  4.5694   4.408959      14.137947  0.75781
# 3       9.0  3.6934  3.5275   5.354473      18.744882  0.47461
# 4       9.0  2.7062  1.9745  21.898415      91.396075  0.20508

# %%
reading.res_unfold.head()
# Out:
#    Molecule       f  f_next    x_ssDNA  N_nucleotides      t_0
# 0       9.0  3.1392  2.4623  20.307173      77.604329  0.56445
# 1       9.0  3.8925  3.0363  24.326300      82.949070  0.68653
# 2       9.0  3.1890  3.2753   2.336475       8.849825  0.50977
# 3       9.0  5.0008  4.7420   7.559767      23.032276  0.91211
# 4       9.0  6.0162  5.3127  18.431678      52.349439  1.16113

# %%
# f_max = f_MAX[4]
# colors = ["#7afdd6","#77ff94","#a1e44d","#60993e","#613a3a", 
#             "#e3b505","#95190c","#610345","#107e7d","#044b7f"]
# markers = ["D", "o", "v", "^", "1", "8", "s", "p", "*", "x"]

# for m in range(len(molecules)):
#     col = colors[m]
#     for i in range(len(all_molecules_f[m])):
#         lab = f'Molecule {m}' if i == 0 else ''
#         f, f_next, x_ssDNA, N_nucleotides, t_0 = all_molecules_f[m][i][0]
#         plt.scatter(t_0, f_next, c=col, marker=markers[m], label=lab)
# plt.grid()
# plt.legend(loc='best')
# plt.title(f'f_MAX = {f_max} -- Fold')
# # plt.xscale('log')
# plt.xlabel('Time [s]')
# plt.ylabel('$f_{rupture} \\:[pN]$')
# plt.show()

# %%
# Create folder for images
images_path = f'imgs/{folder}/{f_max}'
isExist = os.path.exists(images_path)
if not isExist:
    os.makedirs(images_path)
    print("The images directory is created...")
# Out:
# The images directory is created...

# %%
colors = ["#7afdd6","#77ff94","#a1e44d","#60993e","#613a3a", 
            "#e3b505","#95190c","#610345","#107e7d","#044b7f", 
            "#20bf55","#0b4f6c","#01baef","#fbfbff","#757575"]
markers = ["D", "o", "v", "^", "1", "8", "s", "p", "*", "x", 
           "d", "|", "_", "4", "P"]

fig, ax = plt.subplots(3, figsize=(12, 20))
g = 0

for m in range(len(molecules)):
    col = colors[m]
    for i in range(len(all_molecules_f[m])):
        g += 1
        lab = f'Molecule {molecules[m]}' if i == 0 else ''
        f, f_next, x_ssDNA, N_nucleotides, t_0 = all_molecules_f[m][i][0]
        ax[0].scatter(t_0, f_next, c=col, marker=markers[m], label=lab)
        ax[1].scatter(g, x_ssDNA, c=col, marker=markers[m], label=lab)
        ax[2].scatter(g, N_nucleotides, c=col, marker=markers[m], label=lab)

ax[0].grid()
ax[0].legend(loc='best')
ax[0].set_title(f'f_MAX = {f_max} -- Folding')
ax[0].set_xlabel('Time [s]')
ax[0].set_ylabel('$f_{rupture} \\:[pN]$')

ax[1].grid()
ax[1].legend()
ax[1].set_title('$x_{ssDNA}$')
ax[1].set_ylabel('$x_{ssDNA}$')

ax[2].grid()
ax[2].legend()
ax[2].set_title('# of nucleotides')
ax[2].set_ylabel('$N_{nucleotides}$')

plt.savefig(f'imgs/{folder}/{f_max}/f_MAX_{f_max}_Folding.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# for m in range(len(molecules)):
#     col = colors[m]
#     for i in range(len(all_molecules_u[m])):
#         lab = f'Molecule {molecules[m]}' if i == 0 else ''
#         f, f_next, x_ss_DNA, N_nucleotides, t_0 = all_molecules_u[m][i][0]
#         plt.scatter(t_0, f, c=col, marker=markers[m], label=lab)
#     plt.grid()
#     plt.legend(loc='best')
#     plt.title(f'f_MAX = {f_max} -- Unfolding')
#     plt.xlabel('Time [s]')
#     plt.ylabel('$f_{rupture} \\:[pN]$')
#     plt.show()

# %%
for m in range(len(molecules)):
    fig, ax = plt.subplots(3, figsize=(8, 18))
    col = colors[m]
    g = 0
    for i in range(len(all_molecules_u[m])):
        g += 1 
        lab = f'Molecule {molecules[m]}' if i == 0 else ''
        f, f_next, x_ssDNA, N_nucleotides, t_0 = all_molecules_u[m][i][0]
        ax[0].scatter(t_0, f, c=col, marker=markers[m], label=lab)
        ax[1].scatter(g, x_ssDNA, c=col, marker=markers[m], label=lab)
        ax[2].scatter(g, N_nucleotides, c=col, marker=markers[m], label=lab)
    ax[0].grid()
    ax[0].legend(loc='best')
    ax[0].set_title(f'f_MAX = {f_max} -- Unfolding')
    ax[0].set_xlabel('Time [s]')
    ax[0].set_ylabel('$f_{rupture} \\:[pN]$')

    ax[1].grid()
    ax[1].legend()
    ax[1].set_title('$x_{ssDNA}$')
    ax[1].set_ylabel('$x_{ssDNA}$')

    ax[2].grid()
    ax[2].legend()
    ax[2].set_title('# of nucleotides')
    ax[2].set_ylabel('$N_{nucleotides}$')
    plt.savefig(f'imgs/{folder}/{f_max}/f_MAX_{f_max}_Unolding_Molecule{molecules[m]}.png', dpi=300, bbox_inches='tight')
    plt.show()
