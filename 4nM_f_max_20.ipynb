# %%
import numpy as np
import matplotlib.pyplot as plt
from files_sorting import Txt_Reading
import pandas as pd
import os

# %matplotlib inline

# %%
folder = "4nM"
f_MAX = [10, 15, 20, 25, 30, 35]
f_max = 20
reading = Txt_Reading(folder, f_max)

# %%
file = reading.readTxt(number=3, N=1, ty='f', graph=True)
# Out:
# The break point λ_0 [0.027290726773799356] could be smaller/higher than expected
# or the rupture force [2.0174] smaller/higher than expected
# Reshape of 5 performed

# %%
reading.params_df
# Out:
#    f_rupture  f_rupture_next   x_ssDNA  N_nucleotides      t_0       λ_0  \
# 0     7.8013          7.8461  2.420946       6.331435  4.61182  0.229149
#
#        a_pre     b_pre     a_post    b_post
# 0  26.630323  1.283172  29.988204  0.005292

# %%
# plt.plot(reading.λ[:600], reading.force_Y[:600])
# plt.scatter(reading.λ_0, reading.f_rupture, marker="^", c="red")
# plt.scatter(reading.λ[(reading.index+1)[0]], reading.f_rupture_next, marker="v", c="orange", s=1000);

# %%
reading.f_rupture, reading.f_rupture_next
# Out:
# ([7.8013], [7.8461])

# %%
file = reading.readTxt(number=3, N=7, ty='f', graph=True)
reading.params_df
# Out:
#    f_rupture  f_rupture_next    x_ssDNA  N_nucleotides      t_0      λ_0  \
# 0     6.3566           5.746  16.705878      46.556571  2.98535  0.28995
#
#        a_pre     b_pre     a_post    b_post
# 0  15.613574  1.164555  21.167483 -0.458472

# %%
# Columns: CycleCount, X_force,	Y_force, Z_force, time(sec), Status, λ

# %%
molecules, all_molecules_f, all_molecules_u = reading.sequential_analysis()
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# Not saving file Data/4nM/20/3/1_f.txt
# Not saving file Data/4nM/20/3/3_f.txt
# Not saving file Data/4nM/20/3/8_f.txt
# Not saving file Data/4nM/20/3/11_f.txt
# Not saving file Data/4nM/20/3/14_f.txt
# Not saving file Data/4nM/20/3/15_f.txt
# Not saving file Data/4nM/20/3/17_f.txt
# Not saving file Data/4nM/20/3/22_f.txt
# Not saving file Data/4nM/20/3/23_f.txt
# Not saving file Data/4nM/20/3/26_f.txt
# Not saving file Data/4nM/20/3/27_f.txt
# Not saving file Data/4nM/20/3/30_f.txt
# Not saving file Data/4nM/20/3/34_f.txt
# Not saving file Data/4nM/20/3/35_f.txt
# Not saving file Data/4nM/20/3/37_f.txt
# Not saving file Data/4nM/20/3/41_f.txt
# Not saving file Data/4nM/20/3/44_f.txt
# Not saving file Data/4nM/20/3/1_u.txt
# Not saving file Data/4nM/20/3/14_u.txt
# Not saving file Data/4nM/20/3/17_u.txt
# Not saving file Data/4nM/20/3/23_u.txt
# Not saving file Data/4nM/20/3/37_u.txt
# Not saving file Data/4nM/20/8/1_f.txt
# Not saving file Data/4nM/20/8/2_f.txt
# Not saving file Data/4nM/20/8/6_f.txt
# Not saving file Data/4nM/20/8/7_f.txt
# Not saving file Data/4nM/20/8/8_f.txt
# Not saving file Data/4nM/20/8/9_f.txt
# Not saving file Data/4nM/20/8/11_f.txt
# Not saving file Data/4nM/20/8/12_f.txt
# Not saving file Data/4nM/20/8/34_f.txt
# Not saving file Data/4nM/20/8/37_f.txt
# Not saving file Data/4nM/20/8/38_f.txt
# Not saving file Data/4nM/20/8/39_f.txt
# Not saving file Data/4nM/20/8/1_u.txt
# Not saving file Data/4nM/20/8/6_u.txt
# Not saving file Data/4nM/20/8/7_u.txt
# Not saving file Data/4nM/20/8/8_u.txt
# Not saving file Data/4nM/20/8/10_u.txt
# Not saving file Data/4nM/20/8/11_u.txt
# Not saving file Data/4nM/20/8/17_u.txt
# Not saving file Data/4nM/20/8/27_u.txt
# Not saving file Data/4nM/20/8/28_u.txt
# Not saving file Data/4nM/20/8/35_u.txt
# Not saving file Data/4nM/20/8/37_u.txt
# Not saving file Data/4nM/20/8/38_u.txt
# Not saving file Data/4nM/20/12/8_f.txt
# Not saving file Data/4nM/20/12/11_f.txt
# Not saving file Data/4nM/20/12/20_f.txt
# Not saving file Data/4nM/20/12/21_f.txt
# Not saving file Data/4nM/20/12/23_f.txt
# Not saving file Data/4nM/20/12/25_f.txt
# Not saving file Data/4nM/20/12/32_f.txt
# Not saving file Data/4nM/20/12/34_f.txt
# Not saving file Data/4nM/20/12/38_f.txt
# Not saving file Data/4nM/20/12/32_u.txt
# Not saving file Data/4nM/20/12/39_u.txt
# Not saving file Data/4nM/20/18/18_f.txt
# Not saving file Data/4nM/20/18/25_f.txt
# Not saving file Data/4nM/20/18/27_f.txt
# Not saving file Data/4nM/20/18/31_f.txt
# Not saving file Data/4nM/20/18/32_f.txt
# Not saving file Data/4nM/20/18/35_f.txt
# Not saving file Data/4nM/20/18/37_f.txt
# Not saving file Data/4nM/20/18/41_f.txt
# Not saving file Data/4nM/20/18/1_u.txt
# Not saving file Data/4nM/20/18/7_u.txt
# Not saving file Data/4nM/20/18/22_u.txt
# Not saving file Data/4nM/20/18/38_u.txt
# Saving results...

# %%
λ = reading.file[1:, -1]
force_Y = np.abs(reading.file[1:, 2])

# %%
file = reading.readTxt(number=3, N=25, ty='u', graph=True)
# Out:
# The break point λ_0 [0.04936649777326857] could be smaller/higher than expected
# or the rupture force [2.3016] smaller/higher than expected

# %%
reading.params_df
# Out:
#    f_rupture  f_rupture_next    x_ssDNA  N_nucleotides      t_0       λ_0  \
# 0     2.3016          1.7573  10.103146      46.821677  0.27441  0.049366
#
#        a_pre     b_pre     a_post    b_post
# 0  21.402682  1.170004  19.310719  0.961629

# %%
reading.k_eff
# Out:
# 0.05782863661081402

# %%
reading.res_fold.head()
# Out:
#    Molecule       f  f_next    x_ssDNA  N_nucleotides         t_0
# 0       3.0  3.1357  2.7707   8.009853      30.629242    13.44189
# 1       3.0  3.2108  2.6832  15.699390      59.237409  5389.02637
# 2       3.0  2.4343  1.9365  21.592489      96.411101  5397.24121
# 3       3.0  3.9873  3.5592  12.905765      43.493089  5404.78418
# 4       3.0  6.3566  5.7460  16.705878      46.556571  5412.33887

# %%
reading.res_unfold.head()
# Out:
#    Molecule       f  f_next    x_ssDNA  N_nucleotides         t_0
# 0       3.0  6.5519  6.5171   2.065420       5.698313     7.00195
# 1       3.0  4.0184  3.5804  10.119054      33.974158    14.57813
# 2       3.0  8.0887  7.5412  15.121062      39.145972  5391.01660
# 3       3.0  4.8832  4.4004  14.444888      44.442615  5398.43457
# 4       3.0  3.5592  3.0714  16.858556      60.158465  5405.95410

# %%
# f_max = f_MAX[4]
# colors = ["#7afdd6","#77ff94","#a1e44d","#60993e","#613a3a", 
#             "#e3b505","#95190c","#610345","#107e7d","#044b7f"]
# markers = ["D", "o", "v", "^", "1", "8", "s", "p", "*", "x"]

# for m in range(len(molecules)):
#     col = colors[m]
#     for i in range(len(all_molecules_f[m])):
#         lab = f'Molecule {m}' if i == 0 else ''
#         f, f_next, x_ssDNA, N_nucleotides, t_0 = all_molecules_f[m][i][0]
#         plt.scatter(t_0, f_next, c=col, marker=markers[m], label=lab)
# plt.grid()
# plt.legend(loc='best')
# plt.title(f'f_MAX = {f_max} -- Fold')
# # plt.xscale('log')
# plt.xlabel('Time [s]')
# plt.ylabel('$f_{rupture} \\:[pN]$')
# plt.show()

# %%
# Create folder for images
images_path = f'imgs/{folder}/{f_max}'
isExist = os.path.exists(images_path)
if not isExist:
    os.makedirs(images_path)
    print("The images directory is created...")
# Out:
# The images directory is created...

# %%
colors = ["#7afdd6","#77ff94","#a1e44d","#60993e","#613a3a", 
            "#e3b505","#95190c","#610345","#107e7d","#044b7f", 
            "#20bf55","#0b4f6c","#01baef","#fbfbff","#757575"]
markers = ["D", "o", "v", "^", "1", "8", "s", "p", "*", "x", 
           "d", "|", "_", "4", "P"]

fig, ax = plt.subplots(3, figsize=(12, 20))
g = 0

for m in range(len(molecules)):
    col = colors[m]
    for i in range(len(all_molecules_f[m])):
        g += 1
        lab = f'Molecule {molecules[m]}' if i == 0 else ''
        f, f_next, x_ssDNA, N_nucleotides, t_0 = all_molecules_f[m][i][0]
        ax[0].scatter(t_0, f_next, c=col, marker=markers[m], label=lab)
        ax[1].scatter(g, x_ssDNA, c=col, marker=markers[m], label=lab)
        ax[2].scatter(g, N_nucleotides, c=col, marker=markers[m], label=lab)

ax[0].grid()
ax[0].legend(loc='best')
ax[0].set_title(f'f_MAX = {f_max} -- Folding')
ax[0].set_xlabel('Time [s]')
ax[0].set_ylabel('$f_{rupture} \\:[pN]$')

ax[1].grid()
ax[1].legend()
ax[1].set_title('$x_{ssDNA}$')
ax[1].set_ylabel('$x_{ssDNA}$')

ax[2].grid()
ax[2].legend()
ax[2].set_title('# of nucleotides')
ax[2].set_ylabel('$N_{nucleotides}$')

plt.savefig(f'imgs/{folder}/{f_max}/f_MAX_{f_max}_Folding.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(3, figsize=(12, 20))
g = 0

for m in range(len(molecules)):
    col = colors[m]
    for i in range(len(all_molecules_u[m])):
        g += 1
        lab = f'Molecule {molecules[m]}' if i == 0 else ''
        f, f_next, x_ssDNA, N_nucleotides, t_0 = all_molecules_u[m][i][0]
        ax[0].scatter(t_0, f_next, c=col, marker=markers[m], label=lab)
        ax[1].scatter(g, x_ssDNA, c=col, marker=markers[m], label=lab)
        ax[2].scatter(g, N_nucleotides, c=col, marker=markers[m], label=lab)

ax[0].grid()
ax[0].legend(loc='best')
ax[0].set_title(f'f_MAX = {f_max} -- Unfolding')
ax[0].set_xlabel('Time [s]')
ax[0].set_ylabel('$f_{rupture} \\:[pN]$')

ax[1].grid()
ax[1].legend()
ax[1].set_title('$x_{ssDNA}$')
ax[1].set_ylabel('$x_{ssDNA}$')

ax[2].grid()
ax[2].legend()
ax[2].set_title('# of nucleotides')
ax[2].set_ylabel('$N_{nucleotides}$')

plt.savefig(f'imgs/{folder}/{f_max}/f_MAX_{f_max}_Unfolding.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Plots per single molecule

# %%
for m in range(len(molecules)):
    fig, ax = plt.subplots(3, figsize=(8, 18))
    col = colors[m]
    g = 0
    for i in range(len(all_molecules_f[m])):
        g += 1 
        lab = f'Molecule {molecules[m]}' if i == 0 else ''
        f, f_next, x_ssDNA, N_nucleotides, t_0 = all_molecules_f[m][i][0]
        ax[0].scatter(t_0, f, c=col, marker=markers[m], label=lab)
        ax[1].scatter(g, x_ssDNA, c=col, marker=markers[m], label=lab)
        ax[2].scatter(g, N_nucleotides, c=col, marker=markers[m], label=lab)
    ax[0].grid()
    ax[0].legend(loc='best')
    ax[0].set_title(f'f_MAX = {f_max} -- Unfolding')
    ax[0].set_xlabel('Time [s]')
    ax[0].set_ylabel('$f_{rupture} \\:[pN]$')

    ax[1].grid()
    ax[1].legend()
    ax[1].set_title('$x_{ssDNA}$')
    ax[1].set_ylabel('$x_{ssDNA}$')

    ax[2].grid()
    ax[2].legend()
    ax[2].set_title('# of nucleotides')
    ax[2].set_ylabel('$N_{nucleotides}$')
    plt.savefig(f'imgs/{folder}/{f_max}/f_MAX_{f_max}_Folding_Molecule{molecules[m]}.png', dpi=300, bbox_inches='tight')
    plt.show()

# %%
for m in range(len(molecules)):
    fig, ax = plt.subplots(3, figsize=(8, 18))
    col = colors[m]
    g = 0
    for i in range(len(all_molecules_u[m])):
        g += 1 
        lab = f'Molecule {molecules[m]}' if i == 0 else ''
        f, f_next, x_ssDNA, N_nucleotides, t_0 = all_molecules_u[m][i][0]
        ax[0].scatter(t_0, f, c=col, marker=markers[m], label=lab)
        ax[1].scatter(g, x_ssDNA, c=col, marker=markers[m], label=lab)
        ax[2].scatter(g, N_nucleotides, c=col, marker=markers[m], label=lab)
    ax[0].grid()
    ax[0].legend(loc='best')
    ax[0].set_title(f'f_MAX = {f_max} -- Unfolding')
    ax[0].set_xlabel('Time [s]')
    ax[0].set_ylabel('$f_{rupture} \\:[pN]$')

    ax[1].grid()
    ax[1].legend()
    ax[1].set_title('$x_{ssDNA}$')
    ax[1].set_ylabel('$x_{ssDNA}$')

    ax[2].grid()
    ax[2].legend()
    ax[2].set_title('# of nucleotides')
    ax[2].set_ylabel('$N_{nucleotides}$')
    plt.savefig(f'imgs/{folder}/{f_max}/f_MAX_{f_max}_Unfolding_Molecule{molecules[m]}.png', dpi=300, bbox_inches='tight')
    plt.show()
