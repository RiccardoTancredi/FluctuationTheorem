# %%
import numpy as np
import matplotlib.pyplot as plt
from files_sorting import Txt_Reading
import pandas as pd
import os

# %matplotlib inline

# %%
folder = "10nM"
f_MAX = [10, 15, 20, 25, 30, 35]
f_max = 30
reading = Txt_Reading(folder, f_max)

# %%
file = reading.readTxt(number=3, N=1, ty='f', graph=True)
# Out:
# The break point λ_0 [0.0015285207788163502] could be smaller/higher than expected
# or the rupture force [1.8] smaller/higher than expected

# %%
reading.params_df
# Out:
#    f_rupture  f_rupture_next   x_ssDNA  N_nucleotides      t_0       λ_0  \
# 0        1.8          1.1927  19.38339     106.967752  5.86475  0.001529
#
#        a_pre     b_pre     a_post    b_post
# 0  18.732076  1.744808  29.350021  0.735735

# %%
# plt.plot(reading.λ[:600], reading.force_Y[:600])
# plt.scatter(reading.λ_0, reading.f_rupture, marker="^", c="red")
# plt.scatter(reading.λ[(reading.index+1)[0]], reading.f_rupture_next, marker="v", c="orange", s=1000);

# %%
reading.f_rupture, reading.f_rupture_next
# Out:
# ([1.8], [1.1927])

# %%
file = reading.readTxt(number=3, N=7, ty='f', graph=True)
reading.params_df
# Out:
# The break point λ_0 [0.3267765220788134] could be smaller/higher than expected
# or the rupture force [10.7196] smaller/higher than expected
# Reshape of 10 performed
#    f_rupture  f_rupture_next   x_ssDNA  N_nucleotides      t_0       λ_0  \
# 0    3.38844          3.1857  5.456208       19.98626  5.77075  0.050818
#
#        a_pre     b_pre     a_post   b_post
# 0  24.981039  1.997426  29.130801  1.27098

# %%
# Columns: CycleCount, X_force,	Y_force, Z_force, time(sec), Status, λ

# %%
molecules, all_molecules_f, all_molecules_u = reading.sequential_analysis()
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# Not saving file Data/10nM/30/3/1_f.txt
# Not saving file Data/10nM/30/3/3_f.txt
# Not saving file Data/10nM/30/3/4_f.txt
# Not saving file Data/10nM/30/3/5_f.txt
# Not saving file Data/10nM/30/3/7_f.txt
# Not saving file Data/10nM/30/3/8_f.txt
# Not saving file Data/10nM/30/3/9_f.txt
# Not saving file Data/10nM/30/3/11_f.txt
# Not saving file Data/10nM/30/3/12_f.txt
# Not saving file Data/10nM/30/3/14_f.txt
# Not saving file Data/10nM/30/3/15_f.txt
# Not saving file Data/10nM/30/3/16_f.txt
# Not saving file Data/10nM/30/3/18_f.txt
# Not saving file Data/10nM/30/3/19_f.txt
# Not saving file Data/10nM/30/3/21_f.txt
# Not saving file Data/10nM/30/3/22_f.txt
# Not saving file Data/10nM/30/3/24_f.txt
# Not saving file Data/10nM/30/3/26_f.txt
# Not saving file Data/10nM/30/3/27_f.txt
# Not saving file Data/10nM/30/3/29_f.txt
# Not saving file Data/10nM/30/3/30_f.txt
# Not saving file Data/10nM/30/3/31_f.txt
# Not saving file Data/10nM/30/3/32_f.txt
# Not saving file Data/10nM/30/3/33_f.txt
# Not saving file Data/10nM/30/3/34_f.txt
# Not saving file Data/10nM/30/3/37_f.txt
# Not saving file Data/10nM/30/3/3_u.txt
# Not saving file Data/10nM/30/3/7_u.txt
# Not saving file Data/10nM/30/3/12_u.txt
# Not saving file Data/10nM/30/3/13_u.txt
# Not saving file Data/10nM/30/3/15_u.txt
# Not saving file Data/10nM/30/3/32_u.txt
# Not saving file Data/10nM/30/3/33_u.txt
# Not saving file Data/10nM/30/3/35_u.txt
# Not saving file Data/10nM/30/3/36_u.txt
# Not saving file Data/10nM/30/3/37_u.txt
# Not saving file Data/10nM/30/6/3_f.txt
# Not saving file Data/10nM/30/6/4_f.txt
# Not saving file Data/10nM/30/6/1_u.txt
# Not saving file Data/10nM/30/6/2_u.txt
# Not saving file Data/10nM/30/6/3_u.txt
# Not saving file Data/10nM/30/6/4_u.txt
# Not saving file Data/10nM/30/6/6_u.txt
# Not saving file Data/10nM/30/12/1_f.txt
# Not saving file Data/10nM/30/12/2_f.txt
# Not saving file Data/10nM/30/12/4_f.txt
# Not saving file Data/10nM/30/12/5_f.txt
# Not saving file Data/10nM/30/12/7_f.txt
# Not saving file Data/10nM/30/12/8_f.txt
# Not saving file Data/10nM/30/12/10_f.txt
# Not saving file Data/10nM/30/12/12_f.txt
# Not saving file Data/10nM/30/12/13_f.txt
# Not saving file Data/10nM/30/12/1_u.txt
# Not saving file Data/10nM/30/12/2_u.txt
# Not saving file Data/10nM/30/12/5_u.txt
# Not saving file Data/10nM/30/12/7_u.txt
# Not saving file Data/10nM/30/12/8_u.txt
# Not saving file Data/10nM/30/12/10_u.txt
# Not saving file Data/10nM/30/12/12_u.txt
# Not saving file Data/10nM/30/12/13_u.txt
# Not saving file Data/10nM/30/12/14_u.txt
# Not saving file Data/10nM/30/16/1_f.txt
# Not saving file Data/10nM/30/16/2_f.txt
# Not saving file Data/10nM/30/16/4_f.txt
# Not saving file Data/10nM/30/16/7_f.txt
# Not saving file Data/10nM/30/16/13_f.txt
# Not saving file Data/10nM/30/16/16_f.txt
# Not saving file Data/10nM/30/16/17_f.txt
# Not saving file Data/10nM/30/16/21_f.txt
# Not saving file Data/10nM/30/16/29_f.txt
# Not saving file Data/10nM/30/16/32_f.txt
# Not saving file Data/10nM/30/16/3_u.txt
# Not saving file Data/10nM/30/16/4_u.txt
# Not saving file Data/10nM/30/16/5_u.txt
# Not saving file Data/10nM/30/16/7_u.txt
# Not saving file Data/10nM/30/16/8_u.txt
# Not saving file Data/10nM/30/16/10_u.txt
# Not saving file Data/10nM/30/16/11_u.txt
# Not saving file Data/10nM/30/16/12_u.txt
# Not saving file Data/10nM/30/16/13_u.txt
# Not saving file Data/10nM/30/16/15_u.txt
# Not saving file Data/10nM/30/16/16_u.txt
# Not saving file Data/10nM/30/16/18_u.txt
# Not saving file Data/10nM/30/16/22_u.txt
# Not saving file Data/10nM/30/16/24_u.txt
# Not saving file Data/10nM/30/16/28_u.txt
# Not saving file Data/10nM/30/16/33_u.txt
# Saving results...

# %%
λ = reading.file[1:, -1]
force_Y = np.abs(reading.file[1:, 2])

# %%
file = reading.readTxt(number=3, N=25, ty='u', graph=True)

# %%
reading.params_df
# Out:
#    f_rupture  f_rupture_next    x_ssDNA  N_nucleotides      t_0       λ_0  \
# 0     5.2643          4.7616  11.996198      35.805643  0.79736  0.108823
#
#        a_pre   b_pre     a_post    b_post
# 0  25.587262  2.3597  28.689326  1.108863

# %%
reading.k_eff
# Out:
# 0.04674990655724458

# %%
reading.res_fold.head()
# Out:
#    Molecule       f  f_next    x_ssDNA  N_nucleotides        t_0
# 0       3.0  2.8253  2.2430  12.647339      51.411987   17.26087
# 1       3.0  6.0640  5.5663  14.310533      40.531816   91.44080
# 2       3.0  8.0617  7.5042  13.664414      35.407732  138.37244
# 3       3.0  3.7876  3.2385  12.783694      44.186240  175.21057
# 4       3.0  4.7964  4.1991  14.389134      44.604711  221.21179

# %%
reading.res_unfold.head()
# Out:
#    Molecule       f  f_next    x_ssDNA  N_nucleotides       t_0
# 0       3.0  3.8457  3.3629  13.061636      44.805288  -5.30163
# 1       3.0  2.1135  1.6506  12.113444      59.521650   5.99097
# 2       3.0  7.4776  6.9467  14.986470      39.678356  70.51013
# 3       3.0  4.1460  3.6267  11.322053      37.452115  81.19336
# 4       3.0  6.0574  5.5397  14.983790      42.454875  93.64649

# %%
# f_max = f_MAX[4]
# colors = ["#7afdd6","#77ff94","#a1e44d","#60993e","#613a3a", 
#             "#e3b505","#95190c","#610345","#107e7d","#044b7f"]
# markers = ["D", "o", "v", "^", "1", "8", "s", "p", "*", "x"]

# for m in range(len(molecules)):
#     col = colors[m]
#     for i in range(len(all_molecules_f[m])):
#         lab = f'Molecule {m}' if i == 0 else ''
#         f, f_next, x_ssDNA, N_nucleotides, t_0 = all_molecules_f[m][i][0]
#         plt.scatter(t_0, f_next, c=col, marker=markers[m], label=lab)
# plt.grid()
# plt.legend(loc='best')
# plt.title(f'f_MAX = {f_max} -- Fold')
# # plt.xscale('log')
# plt.xlabel('Time [s]')
# plt.ylabel('$f_{rupture} \\:[pN]$')
# plt.show()

# %%
# Create folder for images
images_path = f'imgs/{folder}/{f_max}'
isExist = os.path.exists(images_path)
if not isExist:
    os.makedirs(images_path)
    print("The images directory is created...")
# Out:
# The images directory is created...

# %%
colors = ["#7afdd6","#77ff94","#a1e44d","#60993e","#613a3a", 
            "#e3b505","#95190c","#610345","#107e7d","#044b7f", 
            "#20bf55","#0b4f6c","#01baef","#fbfbff","#757575"]
markers = ["D", "o", "v", "^", "1", "8", "s", "p", "*", "x", 
           "d", "|", "_", "4", "P"]

fig, ax = plt.subplots(3, figsize=(12, 20))
g = 0

for m in range(len(molecules)):
    col = colors[m]
    for i in range(len(all_molecules_f[m])):
        g += 1
        lab = f'Molecule {molecules[m]}' if i == 0 else ''
        f, f_next, x_ssDNA, N_nucleotides, t_0 = all_molecules_f[m][i][0]
        ax[0].scatter(t_0, f_next, c=col, marker=markers[m], label=lab)
        ax[1].scatter(g, x_ssDNA, c=col, marker=markers[m], label=lab)
        ax[2].scatter(g, N_nucleotides, c=col, marker=markers[m], label=lab)

ax[0].grid()
ax[0].legend(loc='best')
ax[0].set_title(f'f_MAX = {f_max} -- Folding')
ax[0].set_xlabel('Time [s]')
ax[0].set_ylabel('$f_{rupture} \\:[pN]$')

ax[1].grid()
ax[1].legend()
ax[1].set_title('$x_{ssDNA}$')
ax[1].set_ylabel('$x_{ssDNA}$')

ax[2].grid()
ax[2].legend()
ax[2].set_title('# of nucleotides')
ax[2].set_ylabel('$N_{nucleotides}$')

plt.savefig(f'imgs/{folder}/{f_max}/f_MAX_{f_max}_Folding.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(3, figsize=(12, 20))
g = 0

for m in range(len(molecules)):
    col = colors[m]
    for i in range(len(all_molecules_u[m])):
        g += 1
        lab = f'Molecule {molecules[m]}' if i == 0 else ''
        f, f_next, x_ssDNA, N_nucleotides, t_0 = all_molecules_u[m][i][0]
        ax[0].scatter(t_0, f_next, c=col, marker=markers[m], label=lab)
        ax[1].scatter(g, x_ssDNA, c=col, marker=markers[m], label=lab)
        ax[2].scatter(g, N_nucleotides, c=col, marker=markers[m], label=lab)

ax[0].grid()
ax[0].legend(loc='best')
ax[0].set_title(f'f_MAX = {f_max} -- Unfolding')
ax[0].set_xlabel('Time [s]')
ax[0].set_ylabel('$f_{rupture} \\:[pN]$')

ax[1].grid()
ax[1].legend()
ax[1].set_title('$x_{ssDNA}$')
ax[1].set_ylabel('$x_{ssDNA}$')

ax[2].grid()
ax[2].legend()
ax[2].set_title('# of nucleotides')
ax[2].set_ylabel('$N_{nucleotides}$')

plt.savefig(f'imgs/{folder}/{f_max}/f_MAX_{f_max}_Unfolding.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Plots per single molecule

# %%
for m in range(len(molecules)):
    fig, ax = plt.subplots(3, figsize=(8, 18))
    col = colors[m]
    g = 0
    for i in range(len(all_molecules_f[m])):
        g += 1 
        lab = f'Molecule {molecules[m]}' if i == 0 else ''
        f, f_next, x_ssDNA, N_nucleotides, t_0 = all_molecules_f[m][i][0]
        ax[0].scatter(t_0, f, c=col, marker=markers[m], label=lab)
        ax[1].scatter(g, x_ssDNA, c=col, marker=markers[m], label=lab)
        ax[2].scatter(g, N_nucleotides, c=col, marker=markers[m], label=lab)
    ax[0].grid()
    ax[0].legend(loc='best')
    ax[0].set_title(f'f_MAX = {f_max} -- Unfolding')
    ax[0].set_xlabel('Time [s]')
    ax[0].set_ylabel('$f_{rupture} \\:[pN]$')

    ax[1].grid()
    ax[1].legend()
    ax[1].set_title('$x_{ssDNA}$')
    ax[1].set_ylabel('$x_{ssDNA}$')

    ax[2].grid()
    ax[2].legend()
    ax[2].set_title('# of nucleotides')
    ax[2].set_ylabel('$N_{nucleotides}$')
    plt.savefig(f'imgs/{folder}/{f_max}/f_MAX_{f_max}_Folding_Molecule{molecules[m]}.png', dpi=300, bbox_inches='tight')
    plt.show()

# %%
for m in range(len(molecules)):
    fig, ax = plt.subplots(3, figsize=(8, 18))
    col = colors[m]
    g = 0
    for i in range(len(all_molecules_u[m])):
        g += 1 
        lab = f'Molecule {molecules[m]}' if i == 0 else ''
        f, f_next, x_ssDNA, N_nucleotides, t_0 = all_molecules_u[m][i][0]
        ax[0].scatter(t_0, f, c=col, marker=markers[m], label=lab)
        ax[1].scatter(g, x_ssDNA, c=col, marker=markers[m], label=lab)
        ax[2].scatter(g, N_nucleotides, c=col, marker=markers[m], label=lab)
    ax[0].grid()
    ax[0].legend(loc='best')
    ax[0].set_title(f'f_MAX = {f_max} -- Unfolding')
    ax[0].set_xlabel('Time [s]')
    ax[0].set_ylabel('$f_{rupture} \\:[pN]$')

    ax[1].grid()
    ax[1].legend()
    ax[1].set_title('$x_{ssDNA}$')
    ax[1].set_ylabel('$x_{ssDNA}$')

    ax[2].grid()
    ax[2].legend()
    ax[2].set_title('# of nucleotides')
    ax[2].set_ylabel('$N_{nucleotides}$')
    plt.savefig(f'imgs/{folder}/{f_max}/f_MAX_{f_max}_Unfolding_Molecule{molecules[m]}.png', dpi=300, bbox_inches='tight')
    plt.show()
