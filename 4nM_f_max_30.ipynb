# %%
import numpy as np
import matplotlib.pyplot as plt
from files_sorting import Txt_Reading
import pandas as pd
import os

# %matplotlib inline

# %%
folder = "4nM"
f_MAX = [10, 15, 20, 25, 30, 35]
f_max = 30
reading = Txt_Reading(folder, f_max)

# %%
file = reading.readTxt(number=2, N=1, ty='f', graph=True)

# %%
reading.params_df
# Out:
#    f_rupture  f_rupture_next    x_ssDNA  N_nucleotides      t_0      λ_0  \
# 0     5.0534          4.5225  12.680469      38.469521  6.14844  0.12853
#
#       a_pre     b_pre     a_post    b_post
# 0  27.52776  1.492718  33.096424 -0.088146

# %%
# plt.plot(reading.λ[:600], reading.force_Y[:600])
# plt.scatter(reading.λ_0, reading.f_rupture, marker="^", c="red")
# plt.scatter(reading.λ[(reading.index+1)[0]], reading.f_rupture_next, marker="v", c="orange", s=1000);

# %%
reading.f_rupture, reading.f_rupture_next
# Out:
# ([5.0534], [4.5225])

# %%
file = reading.readTxt(number=2, N=7, ty='f', graph=True)
reading.params_df
# Out:
#    f_rupture  f_rupture_next    x_ssDNA  N_nucleotides     t_0       λ_0  \
# 0      4.783          4.1708  14.598565       45.30738  6.2832  0.085022
#
#        a_pre     b_pre  a_post    b_post
# 0  23.877418  2.369296  28.489  1.105023

# %%
# Columns: CycleCount, X_force,	Y_force, Z_force, time(sec), Status, λ

# %%
molecules, all_molecules_f, all_molecules_u = reading.sequential_analysis()
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# Not saving file Data/4nM/30/2/4_f.txt
# Not saving file Data/4nM/30/2/5_f.txt
# Not saving file Data/4nM/30/2/15_f.txt
# Not saving file Data/4nM/30/2/18_f.txt
# Not saving file Data/4nM/30/2/20_f.txt
# Not saving file Data/4nM/30/2/22_f.txt
# Not saving file Data/4nM/30/2/26_f.txt
# Not saving file Data/4nM/30/2/29_f.txt
# Not saving file Data/4nM/30/2/30_f.txt
# Not saving file Data/4nM/30/2/1_u.txt
# Not saving file Data/4nM/30/2/2_u.txt
# Not saving file Data/4nM/30/2/3_u.txt
# Not saving file Data/4nM/30/2/5_u.txt
# Not saving file Data/4nM/30/2/7_u.txt
# Not saving file Data/4nM/30/2/10_u.txt
# Not saving file Data/4nM/30/2/13_u.txt
# Not saving file Data/4nM/30/2/14_u.txt
# Not saving file Data/4nM/30/2/19_u.txt
# Not saving file Data/4nM/30/2/20_u.txt
# Not saving file Data/4nM/30/2/21_u.txt
# Not saving file Data/4nM/30/2/22_u.txt
# Not saving file Data/4nM/30/2/23_u.txt
# Not saving file Data/4nM/30/2/25_u.txt
# Not saving file Data/4nM/30/2/27_u.txt
# Not saving file Data/4nM/30/2/28_u.txt
# Not saving file Data/4nM/30/2/30_u.txt
# Not saving file Data/4nM/30/6/3_f.txt
# Not saving file Data/4nM/30/6/6_f.txt
# Not saving file Data/4nM/30/6/11_f.txt
# Not saving file Data/4nM/30/6/12_f.txt
# Not saving file Data/4nM/30/6/14_f.txt
# Not saving file Data/4nM/30/6/15_f.txt
# Not saving file Data/4nM/30/6/1_u.txt
# Not saving file Data/4nM/30/6/2_u.txt
# Not saving file Data/4nM/30/6/4_u.txt
# Not saving file Data/4nM/30/6/5_u.txt
# Not saving file Data/4nM/30/6/10_u.txt
# Not saving file Data/4nM/30/6/12_u.txt
# Not saving file Data/4nM/30/6/13_u.txt
# Not saving file Data/4nM/30/6/14_u.txt
# Not saving file Data/4nM/30/6/15_u.txt
# Not saving file Data/4nM/30/8/4_f.txt
# Not saving file Data/4nM/30/8/5_f.txt
# Not saving file Data/4nM/30/8/6_f.txt
# Not saving file Data/4nM/30/8/7_f.txt
# Not saving file Data/4nM/30/8/8_f.txt
# Not saving file Data/4nM/30/8/9_f.txt
# Not saving file Data/4nM/30/8/12_f.txt
# Not saving file Data/4nM/30/8/22_f.txt
# Not saving file Data/4nM/30/8/23_f.txt
# Not saving file Data/4nM/30/8/27_f.txt
# Not saving file Data/4nM/30/8/28_f.txt
# Not saving file Data/4nM/30/8/30_f.txt
# Not saving file Data/4nM/30/8/32_f.txt
# Not saving file Data/4nM/30/8/34_f.txt
# Not saving file Data/4nM/30/8/35_f.txt
# Not saving file Data/4nM/30/8/36_f.txt
# Not saving file Data/4nM/30/8/37_f.txt
# Not saving file Data/4nM/30/8/1_u.txt
# Not saving file Data/4nM/30/8/2_u.txt
# Not saving file Data/4nM/30/8/3_u.txt
# Not saving file Data/4nM/30/8/4_u.txt
# Not saving file Data/4nM/30/8/5_u.txt
# Not saving file Data/4nM/30/8/6_u.txt
# Not saving file Data/4nM/30/8/7_u.txt
# Not saving file Data/4nM/30/8/8_u.txt
# Not saving file Data/4nM/30/8/9_u.txt
# Not saving file Data/4nM/30/8/11_u.txt
# Not saving file Data/4nM/30/8/13_u.txt
# Not saving file Data/4nM/30/8/15_u.txt
# Not saving file Data/4nM/30/8/16_u.txt
# Not saving file Data/4nM/30/8/17_u.txt
# Not saving file Data/4nM/30/8/18_u.txt
# Not saving file Data/4nM/30/8/19_u.txt
# Not saving file Data/4nM/30/8/20_u.txt
# Not saving file Data/4nM/30/8/21_u.txt
# Not saving file Data/4nM/30/8/22_u.txt
# Not saving file Data/4nM/30/8/23_u.txt
# Not saving file Data/4nM/30/8/24_u.txt
# Not saving file Data/4nM/30/8/25_u.txt
# Not saving file Data/4nM/30/8/27_u.txt
# Not saving file Data/4nM/30/8/28_u.txt
# Not saving file Data/4nM/30/8/29_u.txt
# Not saving file Data/4nM/30/8/30_u.txt
# Not saving file Data/4nM/30/8/31_u.txt
# Not saving file Data/4nM/30/8/32_u.txt
# Not saving file Data/4nM/30/8/33_u.txt
# Not saving file Data/4nM/30/8/34_u.txt
# Not saving file Data/4nM/30/8/35_u.txt
# Not saving file Data/4nM/30/8/36_u.txt
# Not saving file Data/4nM/30/8/37_u.txt
# Not saving file Data/4nM/30/15/2_f.txt
# Not saving file Data/4nM/30/15/3_f.txt
# Not saving file Data/4nM/30/15/5_f.txt
# Not saving file Data/4nM/30/15/6_f.txt
# Not saving file Data/4nM/30/15/7_f.txt
# Not saving file Data/4nM/30/15/8_f.txt
# Not saving file Data/4nM/30/15/9_f.txt
# Not saving file Data/4nM/30/15/10_f.txt
# Not saving file Data/4nM/30/15/1_u.txt
# Not saving file Data/4nM/30/15/3_u.txt
# Not saving file Data/4nM/30/15/4_u.txt
# Not saving file Data/4nM/30/15/5_u.txt
# Not saving file Data/4nM/30/15/7_u.txt
# Not saving file Data/4nM/30/15/11_u.txt
# Saving results...

# %%
λ = reading.file[1:, -1]
force_Y = np.abs(reading.file[1:, 2])

# %%
file = reading.readTxt(number=2, N=25, ty='u', graph=True)

# %%
reading.params_df
# Out:
#    f_rupture  f_rupture_next    x_ssDNA  N_nucleotides      t_0       λ_0  \
# 0     3.0757          2.3988  16.105455      62.270379  0.25586  0.027564
#
#        a_pre     b_pre     a_post    b_post
# 0  22.532795  2.359011  28.930249  1.364288

# %%
reading.k_eff
# Out:
# 0.04444316428610126

# %%
molecules, all_molecules_f, all_molecules_u
# Out:
# ([2, 6, 8, 15],
#  [[[[5.0534,
#      4.5225,
#      12.680468557500323,
#      38.46952119570131,
#      6.148440000000846]],
#    [[5.6341, 5.0269, 17.68372300975533, 51.43162205799276, 19.0625]],
#    [[2.8858800000000002,
#      2.5112400000000004,
#      7.5198852500315985,
#      30.181347788750564,
#      33.326170000000275]],
#    [[4.6154, 4.0513, 13.589090310176687, 42.8236175123208, 73.5273500000003]],
#    [[4.783, 4.1708, 14.59856522964551, 45.307380175624345, 86.6132800000014]],
#    [[3.9385,
#      3.3345,
#      14.343092782210963,
#      48.627041039234506,
#      99.35352000000057]],
#    [[4.121, 3.5735, 13.726769069340493, 45.53627390752997, 112.59375]],
#    [[3.7925,
#      3.2748,
#      12.725177416821271,
#      43.95547568903249,
#      125.01563000000169]],
#    [[3.8522, 3.2897, 13.342505417101746, 45.73042958563605, 139.375]],
#    [[3.7526,
#      3.1952,
#      14.885415864984097,
#      51.691698938475966,
#      151.74023999999918]],
#    [[3.8721, 3.2947, 16.010062481053073, 54.7335471915462, 165.25]],
#    [[4.8975,
#      4.3699,
#      13.413619725382272,
#      41.21962883321705,
#      177.77930000000197]],
#    [[5.1065, 4.5291, 17.08001407948125, 51.59880366907934, 351.8496100000011]],
#    [[4.4147,
#      3.8124,
#      15.263418396766538,
#      49.05344486655557,
#      364.7910200000006]],
#    [[3.5442400000000007,
#      3.19916,
#      8.628364114719323,
#      30.857724346688563,
#      391.48047000000224]],
#    [[6.1219, 5.3554, 20.51708396894822, 57.91843906112738, 416.9199200000003]],
#    [[3.6979, 3.1222, 16.0841346438121, 56.27219279734537, 443.7968800000017]],
#    [[5.1314,
#      4.4893,
#      19.227781832041398,
#      57.97410687058951,
#      456.1699200000003]],
#    [[4.5026,
#      3.9053,
#      15.95833134210618,
#      50.838131058666534,
#      469.6093800000017]],
#    [[4.5358,
#      3.9584,
#      17.228651341514944,
#      54.7073901014428,
#      497.31640999999945]],
#    [[3.1726,
#      2.6665400000000004,
#      9.861871634811516,
#      37.46227529193745,
#      511.34375]],
#    [[4.2175199999999995,
#      3.7656,
#      12.839263262343618,
#      42.13275463060986,
#      550.841800000002]]],
#   [[[2.8782,
#      2.49326,
#      10.55236840754375,
#      42.41985913468563,
#      5.779290000000401]],
#    [[3.9486800000000004,
#      3.49542,
#      14.650685668069853,
#      49.60738960236915,
#      18.37206999999944]],
#    [[2.7548,
#      2.1176,
#      13.317378306805761,
#      54.97537379992327,
#      43.482420000000275]],
#    [[2.0479,
#      1.4357,
#      11.449236431952436,
#      57.52125317802999,
#      55.30371000000014]],
#    [[2.1774, 1.7194, 8.460945296259137, 40.72257986922909, 80.44823999999971]],
#    [[3.8896, 3.3919, 12.83789693246364, 43.79138370008252, 93.13964999999916]],
#    [[2.0828,
#      1.381,
#      10.669393209015055,
#      52.96715071082176,
#      105.60742000000027]],
#    [[3.3122, 2.8676, 11.175147326741579, 41.44571241574511, 117.875]],
#    [[3.3521,
#      2.7946,
#      14.520801483240636,
#      53.50238545404442,
#      156.15234000000055]],
#    [[3.3073,
#      2.8543,
#      10.675098695060221,
#      39.62336705530426,
#      193.8417900000004]],
#    [[3.6607,
#      3.2276,
#      10.548762281084498,
#      37.09754462683064,
#      205.8740199999993]]],
#   [[[3.6248,
#      3.2216,
#      11.151124715581878,
#      39.415597362232845,
#      5.259889999999814]],
#    [[4.4809,
#      4.0728,
#      10.451312081299706,
#      33.365887541245286,
#      16.154419999999845]],
#    [[2.84166,
#      2.48792,
#      8.82916666724335,
#      35.76605911808519,
#      27.801639999999907]],
#    [[6.6909,
#      6.0687,
#      15.231562750611209,
#      41.73602101215196,
#      107.71362999999997]],
#    [[5.7751,
#      5.3238,
#      12.062708953515045,
#      34.76593182536877,
#      119.00951999999984]],
#    [[3.7741,
#      3.351,
#      11.553641868954475,
#      40.00630793054452,
#      141.60339999999997]],
#    [[4.9588,
#      4.4013,
#      14.285606437899945,
#      43.67439063186962,
#      152.35033999999996]],
#    [[3.4788,
#      3.0474,
#      10.813100817715162,
#      39.05365302059065,
#      163.80090999999993]],
#    [[4.1159, 3.731, 10.358587831985076, 34.38300769437934, 174.77405]],
#    [[3.9434, 3.5352, 9.724572897792687, 32.94899454144767, 185.7248599999998]],
#    [[4.6203, 4.1524, 12.04631865900642, 37.9443692862932, 196.6314699999998]],
#    [[3.4854,
#      2.8284,
#      16.391832810517585,
#      59.14276225101128,
#      207.88842999999997]],
#    [[3.512, 3.1138, 10.183485911754067, 36.595013209361, 218.96740999999997]],
#    [[5.1977, 4.7298, 11.516072721808724, 34.545431278408884, 229.83582]],
#    [[4.899, 4.3615, 13.814819424207942, 42.44711154068043, 263.2340099999999]],
#    [[5.1479,
#      4.68,
#      12.255214656270047,
#      36.903612328482275,
#      274.29382999999984]],
#    [[5.5063,
#      5.0583,
#      10.251942220392934,
#      30.074434918134646,
#      285.51928999999996]],
#    [[3.9635999999999996,
#      3.56772,
#      8.994073437030005,
#      30.39821463383277,
#      319.63708999999994]],
#    [[6.3326, 5.8945, 11.43543188539637, 31.90939564313605, 341.3944099999999]],
#    [[5.5229,
#      5.0782,
#      11.860085397810051,
#      34.752435692112066,
#      363.8751199999999]]],
#   [[[5.3383, 4.7211, 19.314472514625177, 57.33600955341219, 5.51201999999995]],
#    [[4.0732,
#      3.4659,
#      16.31655002291845,
#      54.427833790470906,
#      78.97808999999995]]]],
#  [[[[2.9363, 2.3789, 14.59925811157232, 57.99458246411773, 33.75977000000057]],
#    [[5.9627, 5.4317, 13.20444268061391, 37.6217323713161, 62.10352000000057]],
#    [[3.7991,
#      3.2615,
#      12.968492850069634,
#      44.756941261945386,
#      87.60547000000224]],
#    [[5.6109,
#      5.0468,
#      14.045166016866059,
#      40.91193422082052,
#      100.65039000000252]],
#    [[3.82132,
#      3.43476,
#      9.234929711338877,
#      31.77892663822426,
#      125.57422000000224]],
#    [[5.0402,
#      4.3898,
#      15.49354974674647,
#      47.053580215233076,
#      140.61719000000085]],
#    [[5.1165,
#      4.5623,
#      13.949766823392146,
#      42.109249612052054,
#      179.49219000000085]],
#    [[5.2469, 4.83708, 11.80610598467463, 35.2840877282523, 352.7461000000003]],
#    [[4.3898,
#      3.7626,
#      15.915534379207815,
#      51.27953424035758,
#      366.01172000000224]],
#    [[2.8501,
#      2.1731,
#      14.831372521422395,
#      59.97318195073558,
#      379.1152399999992]],
#    [[3.2549, 2.6875, 15.8130563742397, 59.214223806119215, 457.3378900000025]],
#    [[2.99972,
#      2.43196,
#      12.50206904306862,
#      49.043948631962834,
#      483.9648500000003]],
#    [[2.9264,
#      2.3191,
#      14.079454750133936,
#      56.041618154061425,
#      525.9257800000014]],
#    [[2.9034799999999996,
#      2.48968,
#      10.156426874993244,
#      40.61568482294938,
#      551.0117200000022]]],
#   [[[3.8498,
#      3.372,
#      11.478295998554588,
#      39.35315166614245,
#      19.203120000000126]],
#    [[3.4317,
#      2.9738,
#      11.662612995933298,
#      42.42957823401946,
#      55.95897999999943]],
#    [[2.7846,
#      2.3167,
#      14.179914293919614,
#      58.15209350030966,
#      68.21581999999944]],
#    [[3.1729, 2.705, 14.125372348729089, 53.65516610498255, 80.88768999999957]],
#    [[3.0305,
#      2.5709000000000004,
#      13.700491755139101,
#      53.426782007259206,
#      93.65721999999914]],
#    [[4.248,
#      3.7005,
#      14.994243137413827,
#      49.04059339540241,
#      118.89647999999943]],
#    [[2.4893,
#      1.8588,
#      12.686199687675352,
#      55.825973701606436,
#      181.37109000000055]],
#    [[3.34906,
#      2.9907,
#      9.032501886477446,
#      33.29701665087511,
#      194.2138699999996]],
#    [[2.5009, 2.028, 9.675319595498832, 42.4486670710946, 206.49022999999943]]],
#   [[[6.1401,
#      5.4698,
#      14.601668429361307,
#      41.177163257984766,
#      109.53942999999981]],
#    [[6.0837, 5.2574, 19.4383527291912, 54.99298846605012, 131.90381000000002]],
#    [[5.9742, 5.5162, 10.609069590118029, 30.206424457526207, 154.07007]],
#    [[7.5869, 6.9431, 14.354802919330325, 37.84452720142726, 287.66345]]],
#   [[[4.3026,
#      3.8178199999999998,
#      12.778540249833085,
#      41.54915196740235,
#      6.535159999999962]],
#    [[2.044, 1.3206, 9.688480619612697, 48.74102874693547, 79.59423999999996]],
#    [[6.0194, 5.3623, 17.5425167820501, 49.81472428083501, 104.73046999999997]],
#    [[6.8755,
#      6.2782,
#      17.46068603096564,
#      47.42973545951988,
#      117.04284999999999]],
#    [[6.5221,
#      6.06018,
#      12.23784665531127,
#      33.81387918606508,
#      128.09630999999996]]]])

# %%
# f_max = f_MAX[4]
# colors = ["#7afdd6","#77ff94","#a1e44d","#60993e","#613a3a", 
#             "#e3b505","#95190c","#610345","#107e7d","#044b7f"]
# markers = ["D", "o", "v", "^", "1", "8", "s", "p", "*", "x"]

# for m in range(len(molecules)):
#     col = colors[m]
#     for i in range(len(all_molecules_f[m])):
#         lab = f'Molecule {m}' if i == 0 else ''
#         f, f_next, x_ssDNA, N_nucleotides, t_0 = all_molecules_f[m][i][0]
#         plt.scatter(t_0, f_next, c=col, marker=markers[m], label=lab)
# plt.grid()
# plt.legend(loc='best')
# plt.title(f'f_MAX = {f_max} -- Fold')
# # plt.xscale('log')
# plt.xlabel('Time [s]')
# plt.ylabel('$f_{rupture} \\:[pN]$')
# plt.show()

# %%
# Create folder for images
images_path = f'imgs/{folder}/{f_max}'
isExist = os.path.exists(images_path)
if not isExist:
    os.makedirs(images_path)
    print("The images directory is created...")
# Out:
# The images directory is created...

# %%
colors = ["#7afdd6","#77ff94","#a1e44d","#60993e","#613a3a", 
            "#e3b505","#95190c","#610345","#107e7d","#044b7f", 
            "#20bf55","#0b4f6c","#01baef","#fbfbff","#757575"]
markers = ["D", "o", "v", "^", "1", "8", "s", "p", "*", "x", 
           "d", "|", "_", "4", "P"]

fig, ax = plt.subplots(3, figsize=(12, 20))
g = 0

for m in range(len(molecules)):
    col = colors[m]
    for i in range(len(all_molecules_f[m])):
        g += 1
        lab = f'Molecule {molecules[m]}' if i == 0 else ''
        f, f_next, x_ssDNA, N_nucleotides, t_0 = all_molecules_f[m][i][0]
        ax[0].scatter(t_0, f_next, c=col, marker=markers[m], label=lab)
        ax[1].scatter(g, x_ssDNA, c=col, marker=markers[m], label=lab)
        ax[2].scatter(g, N_nucleotides, c=col, marker=markers[m], label=lab)

ax[0].grid()
ax[0].legend(loc='best')
ax[0].set_title(f'f_MAX = {f_max} -- Folding')
ax[0].set_xlabel('Time [s]')
ax[0].set_ylabel('$f_{rupture} \\:[pN]$')

ax[1].grid()
ax[1].legend()
ax[1].set_title('$x_{ssDNA}$')
ax[1].set_ylabel('$x_{ssDNA}$')

ax[2].grid()
ax[2].legend()
ax[2].set_title('# of nucleotides')
ax[2].set_ylabel('$N_{nucleotides}$')

plt.savefig(f'imgs/{folder}/{f_max}/f_MAX_{f_max}_Folding.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(3, figsize=(12, 20))
g = 0

for m in range(len(molecules)):
    col = colors[m]
    for i in range(len(all_molecules_u[m])):
        g += 1
        lab = f'Molecule {molecules[m]}' if i == 0 else ''
        f, f_next, x_ssDNA, N_nucleotides, t_0 = all_molecules_u[m][i][0]
        ax[0].scatter(t_0, f_next, c=col, marker=markers[m], label=lab)
        ax[1].scatter(g, x_ssDNA, c=col, marker=markers[m], label=lab)
        ax[2].scatter(g, N_nucleotides, c=col, marker=markers[m], label=lab)

ax[0].grid()
ax[0].legend(loc='best')
ax[0].set_title(f'f_MAX = {f_max} -- Unfolding')
ax[0].set_xlabel('Time [s]')
ax[0].set_ylabel('$f_{rupture} \\:[pN]$')

ax[1].grid()
ax[1].legend()
ax[1].set_title('$x_{ssDNA}$')
ax[1].set_ylabel('$x_{ssDNA}$')

ax[2].grid()
ax[2].legend()
ax[2].set_title('# of nucleotides')
ax[2].set_ylabel('$N_{nucleotides}$')

plt.savefig(f'imgs/{folder}/{f_max}/f_MAX_{f_max}_Unfolding.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Plots per single molecule

# %%
for m in range(len(molecules)):
    fig, ax = plt.subplots(3, figsize=(8, 18))
    col = colors[m]
    g = 0
    for i in range(len(all_molecules_f[m])):
        g += 1 
        lab = f'Molecule {molecules[m]}' if i == 0 else ''
        f, f_next, x_ssDNA, N_nucleotides, t_0 = all_molecules_f[m][i][0]
        ax[0].scatter(t_0, f, c=col, marker=markers[m], label=lab)
        ax[1].scatter(g, x_ssDNA, c=col, marker=markers[m], label=lab)
        ax[2].scatter(g, N_nucleotides, c=col, marker=markers[m], label=lab)
    ax[0].grid()
    ax[0].legend(loc='best')
    ax[0].set_title(f'f_MAX = {f_max} -- Unfolding')
    ax[0].set_xlabel('Time [s]')
    ax[0].set_ylabel('$f_{rupture} \\:[pN]$')

    ax[1].grid()
    ax[1].legend()
    ax[1].set_title('$x_{ssDNA}$')
    ax[1].set_ylabel('$x_{ssDNA}$')

    ax[2].grid()
    ax[2].legend()
    ax[2].set_title('# of nucleotides')
    ax[2].set_ylabel('$N_{nucleotides}$')
    plt.savefig(f'imgs/{folder}/{f_max}/f_MAX_{f_max}_Folding_Molecule{molecules[m]}.png', dpi=300, bbox_inches='tight')
    plt.show()

# %%
for m in range(len(molecules)):
    fig, ax = plt.subplots(3, figsize=(8, 18))
    col = colors[m]
    g = 0
    for i in range(len(all_molecules_u[m])):
        g += 1 
        lab = f'Molecule {molecules[m]}' if i == 0 else ''
        f, f_next, x_ssDNA, N_nucleotides, t_0 = all_molecules_u[m][i][0]
        ax[0].scatter(t_0, f, c=col, marker=markers[m], label=lab)
        ax[1].scatter(g, x_ssDNA, c=col, marker=markers[m], label=lab)
        ax[2].scatter(g, N_nucleotides, c=col, marker=markers[m], label=lab)
    ax[0].grid()
    ax[0].legend(loc='best')
    ax[0].set_title(f'f_MAX = {f_max} -- Unfolding')
    ax[0].set_xlabel('Time [s]')
    ax[0].set_ylabel('$f_{rupture} \\:[pN]$')

    ax[1].grid()
    ax[1].legend()
    ax[1].set_title('$x_{ssDNA}$')
    ax[1].set_ylabel('$x_{ssDNA}$')

    ax[2].grid()
    ax[2].legend()
    ax[2].set_title('# of nucleotides')
    ax[2].set_ylabel('$N_{nucleotides}$')
    plt.savefig(f'imgs/{folder}/{f_max}/f_MAX_{f_max}_Unfolding_Molecule{molecules[m]}.png', dpi=300, bbox_inches='tight')
    plt.show()
