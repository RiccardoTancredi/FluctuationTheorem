# %%
import numpy as np
import matplotlib.pyplot as plt
from files_sorting import Txt_Reading
import pandas as pd
import os

# %matplotlib inline

# %%
folder = "0nM"
f_MAX = [10, 15, 20, 25, 30, 35]
f_max = 10
reading = Txt_Reading(folder, f_max)

# %%
file = reading.readTxt(number=7, N=18, ty='u', forced_reshaped=0, graph=True) # 10 reshape works best
reading.params_df
# Out:
#    f_rupture  f_rupture_next   x_ssDNA  N_nucleotides      t_0      λ_0  \
# 0     4.2239        3.879955  8.817214      28.913882  0.88183  0.23169
#
#        a_pre     b_pre     a_post    b_post  N_fits
# 0  11.746485  1.494122  10.116886  1.535973       2

# %%
# reading.choice(np.array(reading.best).flatten()), reading.linear, reading.best

# %%
file = reading.readTxt(number=6, N=3, ty='u', forced_reshaped=0, graph=True) # Reshape = 20 works better, but N is then worse
reading.params_df
# Out:
# The break point λ_0 [0.4009312621573584] could be smaller/higher than expected
# or the rupture force [5.7403] smaller/higher than expected
# χ² = [4.52375236 0.54223184]
#    f_rupture  f_rupture_next   x_ssDNA  N_nucleotides      t_0       λ_0  \
# 0     5.9019        5.264271  17.46669      49.947674  1.57569  0.399842
#
#        a_pre     b_pre    a_post    b_post  N_fits
# 0  11.015142  1.546998  9.475578  1.475539       2

# %%
reading.choice(np.array(reading.best).flatten()), reading.linear, reading.best
# Out:
# (4,
#  [3, 7, 8],
#  [[1, 3.596234756808263, 27.8722285075821],
#   [2, 6.245997402959471, 31.433102544132126],
#   [4, 2.7111592247371274, 49.94767430201844],
#   [5, 1.2805932232491106, 13.258309978846588],
#   [6, 0.5487517148721276, 32.9010333357761]])

# %%
reading.best, reading.linear
# Out:
# ([[1, 3.596234756808263, 27.8722285075821],
#   [2, 6.245997402959471, 31.433102544132126],
#   [4, 2.7111592247371274, 49.94767430201844],
#   [5, 1.2805932232491106, 13.258309978846588],
#   [6, 0.5487517148721276, 32.9010333357761]],
#  [3, 7, 8])

# %%
file = reading.readTxt(number=6, N=5, ty='f', graph=True)
reading.params_df
# Out:
# The break point λ_0 [0.2829300003128466] could be smaller/higher than expected
# or the rupture force [4.4323] smaller/higher than expected
# χ² = [0.6572825  0.09590978]
#    f_rupture  f_rupture_next    x_ssDNA  N_nucleotides      t_0      λ_0  \
# 0     4.4879        3.798553  18.490898      58.991452  2.30615  0.27702
#
#        a_pre     b_pre    a_post    b_post  N_fits
# 0  11.490058  1.082574  9.423789  1.187976       2

# %%
# plt.plot(reading.λ[:600], reading.force_Y[:600])
# plt.scatter(reading.λ_0, reading.f_rupture, marker="^", c="red")
# plt.scatter(reading.λ[(reading.index+1)[0]], reading.f_rupture_next, marker="v", c="orange", s=1000);

# %%
reading.bootstrap(reading.λ, reading.force_Y, reading.time, *reading.find_jumps(reading.force_Y))
# Out:
# (21, 0.5754586702303739, 58.991452481826755)

# %%
file = reading.readTxt(number=6, N=7, ty='f', forced_reshaped=0, graph=True)
reading.params_df
# Out:
# The break point λ_0 [0.3409618610047666] could be smaller/higher than expected
# or the rupture force [5.4373] smaller/higher than expected
# χ² = [2.28216811 0.6646676 ]
#    f_rupture  f_rupture_next   x_ssDNA  N_nucleotides     t_0      λ_0  \
# 0      5.205        4.586232  17.68753      53.028849  2.3164  0.34099
#
#        a_pre    b_pre    a_post   b_post  N_fits
# 0  10.840041  1.37511  8.008104  1.85555       2

# %%
# Columns: CycleCount, X_force,	Y_force, Z_force, time(sec), Status, λ

# %%
file = reading.readTxt(number=19, N=7, ty='u', forced_reshaped=0, graph=True) # 10 reshape works best
reading.params_df
# Out:
# The break point λ_0 [0.029465454627496855] could be smaller/higher than expected
# or the rupture force [1.4596] smaller/higher than expected
# χ² = [0.37209354 0.05563496]
#    f_rupture  f_rupture_next    x_ssDNA  N_nucleotides      t_0       λ_0  \
# 0    5.39605        4.922651  11.004918      32.533256  1.03213  0.376541
#
#        a_pre     b_pre     a_post    b_post  N_fits
# 0  11.949376  0.883188  10.824471  0.846791       2

# %%
reading.linear, reading.best, reading.choice(np.array(reading.best).flatten())
# Out:
# ([5, 8],
#  [[2, 2.6735940602834423, 22.721192147432415],
#   [3, 1.76906921682021, 25.317789555406332],
#   [4, 0.979029404013649, 29.37364425206607],
#   [6, 0.2781748096929542, 32.533256287141356],
#   [7, 0.15870105325217057, 31.030390067511195]],
#  6)

# %%
reading.k_eff
# Out:
# 0.04857605207357997

# %%
file = reading.readTxt(number=7, N=43, ty='u', forced_reshaped=0, graph=True) # 10 reshape works best
reading.params_df
# Out:
# The break point λ_0 [0.14819106690727474] could be smaller/higher than expected
# or the rupture force [3.1415] smaller/higher than expected
# χ² = [3.67456412 0.56322369]
#    f_rupture  f_rupture_next    x_ssDNA  N_nucleotides      t_0       λ_0  \
# 0     3.0944        2.534286  12.108586      46.654211  0.49316  0.137875
#
#        a_pre     b_pre     a_post    b_post  N_fits
# 0  11.520268  1.423055  10.772581  1.049014       2

# %%
reading.choice(np.array(reading.best).flatten()), reading.linear, reading.best
# Out:
# (3,
#  [5, 7],
#  [[2, 7.497031674037069, 42.3876913467991],
#   [3, 2.8161184580916228, 46.65421062179004],
#   [4, 1.0722011174973982, 39.99903401203539],
#   [6, 0.38390415755227153, 37.1267653250943],
#   [8, 0.246809853399804, 30.65267254971813]])

# %%
file = reading.readTxt(number=7, N=29, ty='u', forced_reshaped=0, graph=True) # 10 reshape works best
reading.params_df
# Out:
# The break point λ_0 [0.06356760115784507] could be smaller/higher than expected
# or the rupture force [2.3672] smaller/higher than expected
# χ² = [2.50766909 6.06058535]
#    f_rupture  f_rupture_next   x_ssDNA  N_nucleotides      t_0       λ_0  \
# 0     4.2088        3.936645  7.012246      23.033219  0.68848  0.241515
#
#        a_pre     b_pre    a_post    b_post  N_fits
# 0  11.745723  1.388822  2.866218  3.244409       2

# %%
reading.linear, reading.best, reading.choice(np.array(reading.best).flatten())
# Out:
# ([3, 4, 5, 6, 7, 8], [[2, 6.060585349032775, 23.033219207703713]], 2)

# %%
molecules, all_molecules_f, all_molecules_u = reading.sequential_analysis()
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]
# Not saving file Data/0nM/10/6/9_u.txt
# Not saving file Data/0nM/10/7/2_f.txt
# Not saving file Data/0nM/10/7/3_f.txt
# Not saving file Data/0nM/10/7/4_f.txt
# Not saving file Data/0nM/10/7/5_f.txt
# Not saving file Data/0nM/10/7/6_f.txt
# Not saving file Data/0nM/10/7/7_f.txt
# Not saving file Data/0nM/10/7/66_f.txt
# Not saving file Data/0nM/10/7/3_u.txt
# Not saving file Data/0nM/10/7/4_u.txt
# Not saving file Data/0nM/10/7/5_u.txt
# Not saving file Data/0nM/10/7/6_u.txt
# Not saving file Data/0nM/10/7/22_u.txt
# Not saving file Data/0nM/10/7/24_u.txt
# Not saving file Data/0nM/10/7/34_u.txt
# Not saving file Data/0nM/10/7/57_u.txt
# Not saving file Data/0nM/10/8/1_f.txt
# Not saving file Data/0nM/10/8/9_f.txt
# Not saving file Data/0nM/10/8/19_f.txt
# Not saving file Data/0nM/10/8/8_u.txt
# Not saving file Data/0nM/10/12/1_f.txt
# Not saving file Data/0nM/10/12/4_f.txt
# Not saving file Data/0nM/10/12/5_f.txt
# Not saving file Data/0nM/10/12/9_f.txt
# Not saving file Data/0nM/10/13/1_f.txt
# Not saving file Data/0nM/10/13/6_u.txt
# Not saving file Data/0nM/10/14/1_f.txt
# Not saving file Data/0nM/10/14/37_f.txt
# Not saving file Data/0nM/10/14/1_u.txt
# Not saving file Data/0nM/10/15/1_f.txt
# Not saving file Data/0nM/10/15/9_f.txt
# Not saving file Data/0nM/10/15/11_f.txt
# Not saving file Data/0nM/10/15/28_f.txt
# Not saving file Data/0nM/10/15/29_f.txt
# Not saving file Data/0nM/10/15/33_f.txt
# Not saving file Data/0nM/10/15/34_f.txt
# Not saving file Data/0nM/10/15/10_u.txt
# Not saving file Data/0nM/10/15/23_u.txt
# Not saving file Data/0nM/10/15/24_u.txt
# Not saving file Data/0nM/10/15/30_u.txt
# Not saving file Data/0nM/10/15/66_u.txt
# Not saving file Data/0nM/10/18/3_f.txt
# Not saving file Data/0nM/10/18/4_f.txt
# Not saving file Data/0nM/10/18/5_f.txt
# Not saving file Data/0nM/10/18/15_f.txt
# Not saving file Data/0nM/10/18/16_f.txt
# Not saving file Data/0nM/10/18/39_f.txt
# Not saving file Data/0nM/10/18/1_u.txt
# Not saving file Data/0nM/10/18/22_u.txt
# Not saving file Data/0nM/10/18/23_u.txt
# Not saving file Data/0nM/10/18/33_u.txt
# Not saving file Data/0nM/10/18/34_u.txt
# Not saving file Data/0nM/10/18/36_u.txt
# Not saving file Data/0nM/10/19/4_f.txt
# Not saving file Data/0nM/10/19/13_f.txt
# Not saving file Data/0nM/10/19/32_f.txt
# Not saving file Data/0nM/10/19/62_f.txt
# Not saving file Data/0nM/10/19/86_f.txt
# Not saving file Data/0nM/10/19/1_u.txt
# Not saving file Data/0nM/10/19/22_u.txt
# Not saving file Data/0nM/10/19/30_u.txt
# Not saving file Data/0nM/10/19/31_u.txt
# Not saving file Data/0nM/10/19/46_u.txt
# Not saving file Data/0nM/10/20/52_f.txt
# Not saving file Data/0nM/10/20/4_u.txt
# Not saving file Data/0nM/10/20/5_u.txt
# Not saving file Data/0nM/10/20/79_u.txt
# Not saving file Data/0nM/10/21/73_f.txt
# Not saving file Data/0nM/10/21/45_u.txt
# Not saving file Data/0nM/10/21/46_u.txt
# Not saving file Data/0nM/10/22/56_f.txt
# Not saving file Data/0nM/10/22/2_u.txt
# Not saving file Data/0nM/10/22/7_u.txt
# Saving results...

# %%
reading.path
# Out:
# 'Data/0nM/10/22/56_u.txt'

# %%
file = reading.readTxt(number=22, N=4, ty='f', forced_reshaped=0, graph=True) # 10 reshape works best
reading.params_df
# Out:
# The break point λ_0 [0.26366530965409757] could be smaller/higher than expected
# or the rupture force [4.07] smaller/higher than expected
# χ² = [5.98259675 7.71061537]
#    f_rupture  f_rupture_next  x_ssDNA  N_nucleotides      t_0       λ_0  \
# 0       4.07        3.688346   9.1213       30.43772  1.91602  0.263665
#
#        a_pre     b_pre    a_post    b_post  N_fits
# 0  10.472026  1.361816  9.246835  1.250276       2

# %%
reading.change_point(forced_reshaped=5)
# Out:
# ([0.06777603500114951], array([6]), [1.6157])

# %%
reading.best, reading.index, reading.choice(np.array(reading.best).flatten())
# Out:
# ([[1, 23.131846124917047, 30.43772004274595],
#   [2, 3.0113042740861915, 21.526263429331138],
#   [3, 0.8164041252622549, 24.606832518889632]],
#  array([122]),
#  1)

# %%
force_Y_reshaped, λ_reshaped, time_reshaped = reading.reshape(20, 'mean')

# %%
lis = np.where(reading.force_Y>=1)[0].tolist() and np.where(reading.force_Y<=6)[0].tolist()
plt.plot(reading.λ[lis], reading.force_Y[lis]);

# %%
reading.bootstrap(reading.λ, reading.force_Y, reading.time, *reading.find_jumps(reading.force_Y))
# Out:
# (6, inf, 0)

# %%
reading.index_med
# Out:
# array([131])

# %%
plt.plot(reading.λ, reading.force_Y);

# %%
tot = 0
for i in all_molecules_f:
    tot += len(i)
tot # total number of experiments performed
# Out:
# 508

# %%
# λ = reading.file[1:, -1]
# force_Y = np.abs(reading.file[1:, 2])
# plt.plot(λ, force_Y);

# %%
# reading.params_df

# %%
# reading.k_eff

# %%
# f_max = f_MAX[4]
# colors = ["#7afdd6","#77ff94","#a1e44d","#60993e","#613a3a", 
#             "#e3b505","#95190c","#610345","#107e7d","#044b7f"]
# markers = ["D", "o", "v", "^", "1", "8", "s", "p", "*", "x"]

# for m in range(len(molecules)):
#     col = colors[m]
#     for i in range(len(all_molecules_f[m])):
#         lab = f'Molecule {m}' if i == 0 else ''
#         f, f_next, x_ssDNA, N_nucleotides, t_0 = all_molecules_f[m][i][0]
#         plt.scatter(t_0, f_next, c=col, marker=markers[m], label=lab)
# plt.grid()
# plt.legend(loc='best')
# plt.title(f'f_MAX = {f_max} -- Fold')
# # plt.xscale('log')
# plt.xlabel('Time [s]')
# plt.ylabel('$f_{rupture} \\:[pN]$')
# plt.show()

# %%
# Create folder for images
images_path = f'imgs/{folder}/{f_max}'
isExist = os.path.exists(images_path)
if not isExist:
    os.makedirs(images_path)
    print("The images directory is created...")
# Out:
# The images directory is created...

# %%
colors = ["#7afdd6","#77ff94","#a1e44d","#60993e","#613a3a", 
            "#e3b505","#95190c","#610345","#107e7d","#044b7f", 
            "#20bf55","#0b4f6c","#01baef","#fbfbff","#757575"]
markers = ["D", "o", "v", "^", "1", "8", "s", "p", "*", "x", 
           "d", "|", "_", "4", "P"]

fig, ax = plt.subplots(3, figsize=(12, 20))
g = 0
for m in range(len(molecules)):
    col = colors[m]
    for i in range(len(all_molecules_f[m])):
        g += 1
        lab = f'Molecule {molecules[m]}' if i == 0 else ''
        f, f_next, x_ssDNA, N_nucleotides, t_0 = all_molecules_f[m][i][0]
        # if f != 0:
        ax[0].scatter(t_0, f_next, c=col, marker=markers[m], label=lab)
        ax[1].scatter(g, x_ssDNA, c=col, marker=markers[m], label=lab)
        ax[2].scatter(g, N_nucleotides, c=col, marker=markers[m], label=lab)

ax[0].grid()
ax[0].legend(loc='best')
ax[0].set_title(f'f_MAX = {f_max} -- Folding')
ax[0].set_xlabel('Time [s]')
ax[0].set_ylabel('$f_{rupture} \\:[pN]$')

ax[1].grid()
ax[1].legend()
ax[1].set_title('$x_{ssDNA}$')
ax[1].set_ylabel('$x_{ssDNA}$')

ax[2].grid()
ax[2].legend()
ax[2].set_title('# of nucleotides')
ax[2].set_ylabel('$N_{nucleotides}$')

plt.savefig(f'imgs/{folder}/{f_max}/f_MAX_{f_max}_Folding.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(3, figsize=(12, 20))
g = 0

for m in range(len(molecules)):
    col = colors[m]
    for i in range(len(all_molecules_u[m])):
        g += 1
        lab = f'Molecule {molecules[m]}' if i == 0 else ''
        f, f_next, x_ssDNA, N_nucleotides, t_0 = all_molecules_u[m][i][0]
        # if f != 0:
        ax[0].scatter(t_0, f_next, c=col, marker=markers[m], label=lab)
        ax[1].scatter(g, x_ssDNA, c=col, marker=markers[m], label=lab)
        ax[2].scatter(g, N_nucleotides, c=col, marker=markers[m], label=lab)

ax[0].grid()
ax[0].legend(loc='best')
ax[0].set_title(f'f_MAX = {f_max} -- Unfolding')
ax[0].set_xlabel('Time [s]')
ax[0].set_ylabel('$f_{rupture} \\:[pN]$')

ax[1].grid()
ax[1].legend()
ax[1].set_title('$x_{ssDNA}$')
ax[1].set_ylabel('$x_{ssDNA}$')

ax[2].grid()
ax[2].legend()
ax[2].set_title('# of nucleotides')
ax[2].set_ylabel('$N_{nucleotides}$')

plt.savefig(f'imgs/{folder}/{f_max}/f_MAX_{f_max}_Unfolding.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Plots per single molecule

# %%
for m in range(len(molecules)):
    fig, ax = plt.subplots(3, figsize=(8, 18))
    col = colors[m]
    g = 0
    for i in range(len(all_molecules_f[m])):
        g += 1 
        lab = f'Molecule {molecules[m]}' if i == 0 else ''
        f, f_next, x_ssDNA, N_nucleotides, t_0 = all_molecules_f[m][i][0]
        ax[0].scatter(t_0, f, c=col, marker=markers[m], label=lab)
        ax[1].scatter(g, x_ssDNA, c=col, marker=markers[m], label=lab)
        ax[2].scatter(g, N_nucleotides, c=col, marker=markers[m], label=lab)
    ax[0].grid()
    ax[0].legend(loc='best')
    ax[0].set_title(f'f_MAX = {f_max} -- Folding')
    ax[0].set_xlabel('Time [s]')
    ax[0].set_ylabel('$f_{rupture} \\:[pN]$')

    ax[1].grid()
    ax[1].legend()
    ax[1].set_title('$x_{ssDNA}$')
    ax[1].set_ylabel('$x_{ssDNA}$')

    ax[2].grid()
    ax[2].legend()
    ax[2].set_title('# of nucleotides')
    ax[2].set_ylabel('$N_{nucleotides}$')
    plt.savefig(f'imgs/{folder}/{f_max}/f_MAX_{f_max}_Folding_Molecule{molecules[m]}.png', dpi=300, bbox_inches='tight')
    plt.show()

# %%
for m in range(len(molecules)):
    fig, ax = plt.subplots(3, figsize=(8, 18))
    col = colors[m]
    g = 0
    for i in range(len(all_molecules_u[m])):
        g += 1 
        lab = f'Molecule {molecules[m]}' if i == 0 else ''
        f, f_next, x_ssDNA, N_nucleotides, t_0 = all_molecules_u[m][i][0]
        ax[0].scatter(t_0, f, c=col, marker=markers[m], label=lab)
        ax[1].scatter(g, x_ssDNA, c=col, marker=markers[m], label=lab)
        ax[2].scatter(g, N_nucleotides, c=col, marker=markers[m], label=lab)
    ax[0].grid()
    ax[0].legend(loc='best')
    ax[0].set_title(f'f_MAX = {f_max} -- Unfolding')
    ax[0].set_xlabel('Time [s]')
    ax[0].set_ylabel('$f_{rupture} \\:[pN]$')

    ax[1].grid()
    ax[1].legend()
    ax[1].set_title('$x_{ssDNA}$')
    ax[1].set_ylabel('$x_{ssDNA}$')

    ax[2].grid()
    ax[2].legend()
    ax[2].set_title('# of nucleotides')
    ax[2].set_ylabel('$N_{nucleotides}$')
    plt.savefig(f'imgs/{folder}/{f_max}/f_MAX_{f_max}_Unfolding_Molecule{molecules[m]}.png', dpi=300, bbox_inches='tight')
    plt.show()
