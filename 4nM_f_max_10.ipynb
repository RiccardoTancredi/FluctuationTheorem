# %%
import numpy as np
import matplotlib.pyplot as plt
from files_sorting import Txt_Reading
import pandas as pd
import os

# %matplotlib inline

# %%
folder = "4nM"
f_MAX = [10, 15, 20, 25, 30, 35]
f_max = 10
reading = Txt_Reading(folder, f_max)

# %%
file = reading.readTxt(number=1, N=1, ty='f', graph=True)

# %%
reading.params_df
# Out:
#    f_rupture  f_rupture_next   x_ssDNA  N_nucleotides      t_0       λ_0  \
# 0     6.3032          5.9183  10.92397      30.530278  1.05078  0.523871
#
#       a_pre     b_pre   a_post    b_post
# 0  8.136314  1.624186  9.50836  0.989903

# %%
# plt.plot(reading.λ[:600], reading.force_Y[:600])
# plt.scatter(reading.λ_0, reading.f_rupture, marker="^", c="red")
# plt.scatter(reading.λ[(reading.index+1)[0]], reading.f_rupture_next, marker="v", c="orange", s=1000);

# %%
reading.f_rupture, reading.f_rupture_next
# Out:
# ([6.3032], [5.9183])

# %%
file = reading.readTxt(number=1, N=7, ty='f', graph=True)
reading.params_df
# Out:
#    f_rupture  f_rupture_next    x_ssDNA  N_nucleotides    t_0       λ_0  \
# 0     5.0406          4.6523  10.365879      31.479939  0.875  0.402875
#
#       a_pre     b_pre     a_post    b_post
# 0  9.318781  0.941694  10.061103  0.681326

# %%
# Columns: CycleCount, X_force,	Y_force, Z_force, time(sec), Status, λ

# %%
molecules, all_molecules_f, all_molecules_u = reading.sequential_analysis()
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Not saving file Data/4nM/10/1/3_f.txt
# Not saving file Data/4nM/10/1/4_f.txt
# Not saving file Data/4nM/10/1/8_f.txt
# Not saving file Data/4nM/10/1/15_f.txt
# Not saving file Data/4nM/10/1/16_f.txt
# Not saving file Data/4nM/10/1/24_f.txt
# Not saving file Data/4nM/10/1/25_f.txt
# Not saving file Data/4nM/10/1/26_f.txt
# Not saving file Data/4nM/10/1/27_f.txt
# Not saving file Data/4nM/10/1/28_f.txt
# Not saving file Data/4nM/10/1/32_f.txt
# Not saving file Data/4nM/10/1/37_f.txt
# Not saving file Data/4nM/10/1/42_f.txt
# Not saving file Data/4nM/10/1/44_f.txt
# Not saving file Data/4nM/10/1/47_f.txt
# Not saving file Data/4nM/10/1/58_f.txt
# Not saving file Data/4nM/10/1/62_f.txt
# Not saving file Data/4nM/10/1/68_f.txt
# Not saving file Data/4nM/10/1/1_u.txt
# Not saving file Data/4nM/10/1/13_u.txt
# Not saving file Data/4nM/10/1/15_u.txt
# Not saving file Data/4nM/10/1/42_u.txt
# Not saving file Data/4nM/10/1/58_u.txt
# Not saving file Data/4nM/10/12/1_f.txt
# Not saving file Data/4nM/10/12/3_f.txt
# Not saving file Data/4nM/10/12/4_f.txt
# Not saving file Data/4nM/10/12/5_f.txt
# Not saving file Data/4nM/10/12/6_f.txt
# Not saving file Data/4nM/10/12/9_f.txt
# Not saving file Data/4nM/10/12/10_f.txt
# Not saving file Data/4nM/10/12/20_f.txt
# Not saving file Data/4nM/10/12/22_f.txt
# Not saving file Data/4nM/10/12/26_f.txt
# Not saving file Data/4nM/10/12/36_f.txt
# Not saving file Data/4nM/10/12/37_f.txt
# Not saving file Data/4nM/10/12/39_f.txt
# Not saving file Data/4nM/10/12/47_f.txt
# Not saving file Data/4nM/10/12/50_f.txt
# Not saving file Data/4nM/10/12/62_f.txt
# Not saving file Data/4nM/10/12/1_u.txt
# Not saving file Data/4nM/10/12/17_u.txt
# Not saving file Data/4nM/10/12/28_u.txt
# Not saving file Data/4nM/10/12/48_u.txt
# Not saving file Data/4nM/10/12/56_u.txt
# Not saving file Data/4nM/10/12/61_u.txt
# Not saving file Data/4nM/10/14/6_f.txt
# Not saving file Data/4nM/10/14/7_f.txt
# Not saving file Data/4nM/10/14/21_f.txt
# Not saving file Data/4nM/10/14/28_f.txt
# Not saving file Data/4nM/10/14/31_f.txt
# Not saving file Data/4nM/10/14/36_f.txt
# Not saving file Data/4nM/10/14/40_f.txt
# Not saving file Data/4nM/10/14/42_f.txt
# Not saving file Data/4nM/10/14/43_f.txt
# Not saving file Data/4nM/10/14/47_f.txt
# Not saving file Data/4nM/10/14/58_f.txt
# Not saving file Data/4nM/10/14/61_f.txt
# Not saving file Data/4nM/10/14/65_f.txt
# Not saving file Data/4nM/10/14/79_f.txt
# Not saving file Data/4nM/10/14/1_u.txt
# Not saving file Data/4nM/10/14/8_u.txt
# Not saving file Data/4nM/10/14/17_u.txt
# Not saving file Data/4nM/10/14/27_u.txt
# Not saving file Data/4nM/10/14/29_u.txt
# Not saving file Data/4nM/10/14/32_u.txt
# Not saving file Data/4nM/10/14/38_u.txt
# Not saving file Data/4nM/10/14/74_u.txt
# Not saving file Data/4nM/10/14/81_u.txt
# Not saving file Data/4nM/10/16/9_f.txt
# Not saving file Data/4nM/10/16/12_f.txt
# Not saving file Data/4nM/10/16/13_f.txt
# Not saving file Data/4nM/10/16/15_f.txt
# Not saving file Data/4nM/10/16/16_f.txt
# Not saving file Data/4nM/10/16/17_f.txt
# Not saving file Data/4nM/10/16/19_f.txt
# Not saving file Data/4nM/10/16/20_f.txt
# Not saving file Data/4nM/10/16/22_f.txt
# Not saving file Data/4nM/10/16/23_f.txt
# Not saving file Data/4nM/10/16/24_f.txt
# Not saving file Data/4nM/10/16/27_f.txt
# Not saving file Data/4nM/10/16/37_f.txt
# Not saving file Data/4nM/10/16/38_f.txt
# Not saving file Data/4nM/10/16/39_f.txt
# Not saving file Data/4nM/10/16/42_f.txt
# Not saving file Data/4nM/10/16/52_f.txt
# Not saving file Data/4nM/10/16/53_f.txt
# Not saving file Data/4nM/10/16/54_f.txt
# Not saving file Data/4nM/10/16/55_f.txt
# Not saving file Data/4nM/10/16/56_f.txt
# Not saving file Data/4nM/10/16/57_f.txt
# Not saving file Data/4nM/10/16/58_f.txt
# Not saving file Data/4nM/10/16/59_f.txt
# Not saving file Data/4nM/10/16/63_f.txt
# Not saving file Data/4nM/10/16/64_f.txt
# Not saving file Data/4nM/10/16/69_f.txt
# Not saving file Data/4nM/10/16/72_f.txt
# Not saving file Data/4nM/10/16/73_f.txt
# Not saving file Data/4nM/10/16/74_f.txt
# Not saving file Data/4nM/10/16/75_f.txt
# Not saving file Data/4nM/10/16/14_u.txt
# Not saving file Data/4nM/10/16/21_u.txt
# Not saving file Data/4nM/10/16/43_u.txt
# Not saving file Data/4nM/10/16/61_u.txt
# Not saving file Data/4nM/10/16/63_u.txt
# Not saving file Data/4nM/10/16/73_u.txt
# Not saving file Data/4nM/10/20/4_f.txt
# Not saving file Data/4nM/10/20/5_f.txt
# Not saving file Data/4nM/10/20/9_f.txt
# Not saving file Data/4nM/10/20/11_f.txt
# Not saving file Data/4nM/10/20/12_f.txt
# Not saving file Data/4nM/10/20/15_f.txt
# Not saving file Data/4nM/10/20/1_u.txt
# Not saving file Data/4nM/10/20/6_u.txt
# Not saving file Data/4nM/10/20/11_u.txt
# Not saving file Data/4nM/10/20/19_u.txt
# Not saving file Data/4nM/10/20/20_u.txt
# Saving results...

# %%
λ = reading.file[1:, -1]
force_Y = np.abs(reading.file[1:, 2])

# %%
file = reading.readTxt(number=1, N=25, ty='u', graph=True)
# Out:
# The break point λ_0 [0.004278706240856789] could be smaller/higher than expected
# or the rupture force [1.5514] smaller/higher than expected
# Reshape of 5 performed

# %%
reading.params_df
# Out:
#    f_rupture  f_rupture_next   x_ssDNA  N_nucleotides      t_0       λ_0  \
# 0     4.2193          4.2525  1.845154        6.05379  0.66602  0.279485
#
#       a_pre     b_pre    a_post    b_post
# 0  8.563603  1.323614  9.148923  1.175526

# %%
reading.k_eff
# Out:
# 0.04413265949085346

# %%
reading.res_fold.head()
# Out:
#    Molecule       f  f_next    x_ssDNA  N_nucleotides      t_0
# 0       1.0  6.3032  5.9183  10.923970      30.530278  1.05078
# 1       1.0  4.1596  3.5224  17.976532      59.373001  0.56934
# 2       1.0  2.1487  1.5414  12.957143      62.938470  0.13672
# 3       1.0  2.1935  1.6310  10.808946      51.760004  0.04883
# 4       1.0  5.0406  4.6523  10.365879      31.479939  0.87500

# %%
reading.res_unfold.head()
# Out:
#    Molecule       f  f_next    x_ssDNA  N_nucleotides      t_0
# 0       1.0  4.9012  4.8697   1.882425       5.782821  0.95996
# 1       1.0  6.9669  7.0332   2.934062       7.936993  1.39746
# 2       1.0  2.9550  2.3627  16.530158      65.419369  0.35644
# 3       1.0  3.0247  2.5004  13.308942      51.957643  0.42090
# 4       1.0  3.0645  2.5469  12.509023      48.466768  0.32128

# %%
# f_max = f_MAX[4]
# colors = ["#7afdd6","#77ff94","#a1e44d","#60993e","#613a3a", 
#             "#e3b505","#95190c","#610345","#107e7d","#044b7f"]
# markers = ["D", "o", "v", "^", "1", "8", "s", "p", "*", "x"]

# for m in range(len(molecules)):
#     col = colors[m]
#     for i in range(len(all_molecules_f[m])):
#         lab = f'Molecule {m}' if i == 0 else ''
#         f, f_next, x_ssDNA, N_nucleotides, t_0 = all_molecules_f[m][i][0]
#         plt.scatter(t_0, f_next, c=col, marker=markers[m], label=lab)
# plt.grid()
# plt.legend(loc='best')
# plt.title(f'f_MAX = {f_max} -- Fold')
# # plt.xscale('log')
# plt.xlabel('Time [s]')
# plt.ylabel('$f_{rupture} \\:[pN]$')
# plt.show()

# %%
# Create folder for images
images_path = f'imgs/{folder}/{f_max}'
isExist = os.path.exists(images_path)
if not isExist:
    os.makedirs(images_path)
    print("The images directory is created...")
# Out:
# The images directory is created...

# %%
colors = ["#7afdd6","#77ff94","#a1e44d","#60993e","#613a3a", 
            "#e3b505","#95190c","#610345","#107e7d","#044b7f", 
            "#20bf55","#0b4f6c","#01baef","#fbfbff","#757575"]
markers = ["D", "o", "v", "^", "1", "8", "s", "p", "*", "x", 
           "d", "|", "_", "4", "P"]

fig, ax = plt.subplots(3, figsize=(12, 20))
g = 0

for m in range(len(molecules)):
    col = colors[m]
    for i in range(len(all_molecules_f[m])):
        g += 1
        lab = f'Molecule {molecules[m]}' if i == 0 else ''
        f, f_next, x_ssDNA, N_nucleotides, t_0 = all_molecules_f[m][i][0]
        ax[0].scatter(t_0, f_next, c=col, marker=markers[m], label=lab)
        ax[1].scatter(g, x_ssDNA, c=col, marker=markers[m], label=lab)
        ax[2].scatter(g, N_nucleotides, c=col, marker=markers[m], label=lab)

ax[0].grid()
ax[0].legend(loc='best')
ax[0].set_title(f'f_MAX = {f_max} -- Folding')
ax[0].set_xlabel('Time [s]')
ax[0].set_ylabel('$f_{rupture} \\:[pN]$')

ax[1].grid()
ax[1].legend()
ax[1].set_title('$x_{ssDNA}$')
ax[1].set_ylabel('$x_{ssDNA}$')

ax[2].grid()
ax[2].legend()
ax[2].set_title('# of nucleotides')
ax[2].set_ylabel('$N_{nucleotides}$')

plt.savefig(f'imgs/{folder}/{f_max}/f_MAX_{f_max}_Folding.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# for m in range(len(molecules)):
#     col = colors[m]
#     for i in range(len(all_molecules_u[m])):
#         lab = f'Molecule {molecules[m]}' if i == 0 else ''
#         f, f_next, x_ss_DNA, N_nucleotides, t_0 = all_molecules_u[m][i][0]
#         plt.scatter(t_0, f, c=col, marker=markers[m], label=lab)
#     plt.grid()
#     plt.legend(loc='best')
#     plt.title(f'f_MAX = {f_max} -- Unfolding')
#     plt.xlabel('Time [s]')
#     plt.ylabel('$f_{rupture} \\:[pN]$')
#     plt.show()

# %%
for m in range(len(molecules)):
    fig, ax = plt.subplots(3, figsize=(8, 18))
    col = colors[m]
    g = 0
    for i in range(len(all_molecules_u[m])):
        g += 1 
        lab = f'Molecule {molecules[m]}' if i == 0 else ''
        f, f_next, x_ssDNA, N_nucleotides, t_0 = all_molecules_u[m][i][0]
        ax[0].scatter(t_0, f, c=col, marker=markers[m], label=lab)
        ax[1].scatter(g, x_ssDNA, c=col, marker=markers[m], label=lab)
        ax[2].scatter(g, N_nucleotides, c=col, marker=markers[m], label=lab)
    ax[0].grid()
    ax[0].legend(loc='best')
    ax[0].set_title(f'f_MAX = {f_max} -- Unfolding')
    ax[0].set_xlabel('Time [s]')
    ax[0].set_ylabel('$f_{rupture} \\:[pN]$')

    ax[1].grid()
    ax[1].legend()
    ax[1].set_title('$x_{ssDNA}$')
    ax[1].set_ylabel('$x_{ssDNA}$')

    ax[2].grid()
    ax[2].legend()
    ax[2].set_title('# of nucleotides')
    ax[2].set_ylabel('$N_{nucleotides}$')
    plt.savefig(f'imgs/{folder}/{f_max}/f_MAX_{f_max}_Unolding_Molecule{molecules[m]}.png', dpi=300, bbox_inches='tight')
    plt.show()
