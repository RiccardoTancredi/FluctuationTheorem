# %%
import numpy as np
import matplotlib.pyplot as plt
from files_sorting import Txt_Reading
import pandas as pd
import os

# %matplotlib inline

# %%
folder = "10nM"
f_MAX = [10, 15, 20, 25, 30, 35]
f_max = 15
reading = Txt_Reading(folder, f_max)

# %%
file = reading.readTxt(number=2, N=1, ty='f', graph=True)

# %%
reading.params_df
# Out:
#    f_rupture  f_rupture_next    x_ssDNA  N_nucleotides      t_0       λ_0  \
# 0     6.2553          5.7625  12.284811      34.422791  2.12826  0.320978
#
#        a_pre     b_pre     a_post    b_post
# 0  12.627306  1.943192  14.431965  1.255983

# %%
# plt.plot(reading.λ[:600], reading.force_Y[:600])
# plt.scatter(reading.λ_0, reading.f_rupture, marker="^", c="red")
# plt.scatter(reading.λ[(reading.index+1)[0]], reading.f_rupture_next, marker="v", c="orange", s=1000);

# %%
reading.f_rupture, reading.f_rupture_next
# Out:
# ([6.2553], [5.7625])

# %%
file = reading.readTxt(number=2, N=7, ty='f', graph=True)
reading.params_df
# Out:
#    f_rupture  f_rupture_next    x_ssDNA  N_nucleotides      t_0       λ_0  \
# 0     6.0313          5.4638  14.521783      41.208231  2.44902  0.287955
#
#        a_pre     b_pre     a_post    b_post
# 0  12.629106  1.991173  14.378799  1.491296

# %%
# Columns: CycleCount, X_force,	Y_force, Z_force, time(sec), Status, λ

# %%
molecules, all_molecules_f, all_molecules_u = reading.sequential_analysis()
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# Not saving file Data/10nM/15/2/2_f.txt
# Not saving file Data/10nM/15/2/13_f.txt
# Not saving file Data/10nM/15/2/26_f.txt
# Not saving file Data/10nM/15/2/27_f.txt
# Not saving file Data/10nM/15/2/12_u.txt
# Not saving file Data/10nM/15/2/21_u.txt
# Not saving file Data/10nM/15/2/25_u.txt
# Not saving file Data/10nM/15/2/26_u.txt
# Not saving file Data/10nM/15/2/28_u.txt
# Not saving file Data/10nM/15/4/12_f.txt
# Not saving file Data/10nM/15/4/14_f.txt
# Not saving file Data/10nM/15/4/16_f.txt
# Not saving file Data/10nM/15/4/21_f.txt
# Not saving file Data/10nM/15/4/22_f.txt
# Not saving file Data/10nM/15/4/47_f.txt
# Not saving file Data/10nM/15/4/49_f.txt
# Not saving file Data/10nM/15/4/53_f.txt
# Not saving file Data/10nM/15/4/3_u.txt
# Not saving file Data/10nM/15/4/23_u.txt
# Not saving file Data/10nM/15/4/46_u.txt
# Not saving file Data/10nM/15/4/53_u.txt
# Not saving file Data/10nM/15/11/16_f.txt
# Not saving file Data/10nM/15/11/21_f.txt
# Not saving file Data/10nM/15/11/27_f.txt
# Not saving file Data/10nM/15/11/29_f.txt
# Not saving file Data/10nM/15/11/32_f.txt
# Not saving file Data/10nM/15/11/34_f.txt
# Not saving file Data/10nM/15/11/36_f.txt
# Not saving file Data/10nM/15/11/41_f.txt
# Not saving file Data/10nM/15/11/44_f.txt
# Not saving file Data/10nM/15/11/45_f.txt
# Not saving file Data/10nM/15/11/48_f.txt
# Not saving file Data/10nM/15/11/52_f.txt
# Not saving file Data/10nM/15/11/55_f.txt
# Not saving file Data/10nM/15/11/56_f.txt
# Not saving file Data/10nM/15/11/58_f.txt
# Not saving file Data/10nM/15/11/66_f.txt
# Not saving file Data/10nM/15/11/68_f.txt
# Not saving file Data/10nM/15/11/71_f.txt
# Not saving file Data/10nM/15/11/24_u.txt
# Not saving file Data/10nM/15/11/27_u.txt
# Not saving file Data/10nM/15/16/1_f.txt
# Not saving file Data/10nM/15/16/2_f.txt
# Not saving file Data/10nM/15/16/5_f.txt
# Not saving file Data/10nM/15/16/7_f.txt
# Not saving file Data/10nM/15/16/8_f.txt
# Not saving file Data/10nM/15/16/11_f.txt
# Not saving file Data/10nM/15/16/12_f.txt
# Not saving file Data/10nM/15/16/14_f.txt
# Not saving file Data/10nM/15/16/16_f.txt
# Not saving file Data/10nM/15/16/17_f.txt
# Not saving file Data/10nM/15/16/34_f.txt
# Not saving file Data/10nM/15/16/42_f.txt
# Not saving file Data/10nM/15/16/43_f.txt
# Not saving file Data/10nM/15/16/50_f.txt
# Not saving file Data/10nM/15/16/51_f.txt
# Not saving file Data/10nM/15/16/54_f.txt
# Not saving file Data/10nM/15/16/56_f.txt
# Not saving file Data/10nM/15/16/6_u.txt
# Not saving file Data/10nM/15/16/19_u.txt
# Not saving file Data/10nM/15/16/33_u.txt
# Not saving file Data/10nM/15/16/34_u.txt
# Not saving file Data/10nM/15/16/44_u.txt
# Saving results...

# %%
λ = reading.file[1:, -1]
force_Y = np.abs(reading.file[1:, 2])

# %%
file = reading.readTxt(number=2, N=25, ty='u', graph=True)
# Out:
# The break point λ_0 [0.882954079185046] could be smaller/higher than expected
# or the rupture force [14.6324] smaller/higher than expected

# %%
reading.params_df
# Out:
#    f_rupture  f_rupture_next    x_ssDNA  N_nucleotides      t_0       λ_0  \
# 0    14.6324         14.0948  13.032815      29.612753  2.93463  0.882954
#
#        a_pre     b_pre     a_post    b_post
# 0  13.485734  2.329935  11.240939  4.232434

# %%
reading.k_eff
# Out:
# 0.047517629343387296

# %%
reading.res_fold.head()
# Out:
#    Molecule       f  f_next    x_ssDNA  N_nucleotides       t_0
# 0       2.0  6.2553  5.7625  12.284811      34.422791   2.12826
# 1       2.0  3.3302  3.5525   6.568814      24.289772  15.06426
# 2       2.0  2.8059  2.9452   3.966880      16.193001  21.28220
# 3       2.0  3.3633  2.8855  11.685382      42.977111  27.72646
# 4       2.0  2.9154  3.0547   2.770490      11.052274  34.24925

# %%
reading.res_unfold.head()
# Out:
#    Molecule       f  f_next    x_ssDNA  N_nucleotides       t_0
# 0       2.0  5.0756  4.4484  16.903365      51.190031  -2.43211
# 1       2.0  2.9452  2.2882  15.500447      61.464497   3.27418
# 2       2.0  2.9552  2.4176  11.435100      45.253482   9.37676
# 3       2.0  4.0005  3.3932  16.988627      57.161192  15.71632
# 4       2.0  6.9073  6.8078   3.633144       9.854621  22.75553

# %%
# f_max = f_MAX[4]
# colors = ["#7afdd6","#77ff94","#a1e44d","#60993e","#613a3a", 
#             "#e3b505","#95190c","#610345","#107e7d","#044b7f"]
# markers = ["D", "o", "v", "^", "1", "8", "s", "p", "*", "x"]

# for m in range(len(molecules)):
#     col = colors[m]
#     for i in range(len(all_molecules_f[m])):
#         lab = f'Molecule {m}' if i == 0 else ''
#         f, f_next, x_ssDNA, N_nucleotides, t_0 = all_molecules_f[m][i][0]
#         plt.scatter(t_0, f_next, c=col, marker=markers[m], label=lab)
# plt.grid()
# plt.legend(loc='best')
# plt.title(f'f_MAX = {f_max} -- Fold')
# # plt.xscale('log')
# plt.xlabel('Time [s]')
# plt.ylabel('$f_{rupture} \\:[pN]$')
# plt.show()

# %%
# Create folder for images
images_path = f'imgs/{folder}/{f_max}'
isExist = os.path.exists(images_path)
if not isExist:
    os.makedirs(images_path)
    print("The images directory is created...")
# Out:
# The images directory is created...

# %%
colors = ["#7afdd6","#77ff94","#a1e44d","#60993e","#613a3a", 
            "#e3b505","#95190c","#610345","#107e7d","#044b7f", 
            "#20bf55","#0b4f6c","#01baef","#fbfbff","#757575"]
markers = ["D", "o", "v", "^", "1", "8", "s", "p", "*", "x", 
           "d", "|", "_", "4", "P"]

fig, ax = plt.subplots(3, figsize=(12, 20))
g = 0

for m in range(len(molecules)):
    col = colors[m]
    for i in range(len(all_molecules_f[m])):
        g += 1
        lab = f'Molecule {molecules[m]}' if i == 0 else ''
        f, f_next, x_ssDNA, N_nucleotides, t_0 = all_molecules_f[m][i][0]
        ax[0].scatter(t_0, f_next, c=col, marker=markers[m], label=lab)
        ax[1].scatter(g, x_ssDNA, c=col, marker=markers[m], label=lab)
        ax[2].scatter(g, N_nucleotides, c=col, marker=markers[m], label=lab)

ax[0].grid()
ax[0].legend(loc='best')
ax[0].set_title(f'f_MAX = {f_max} -- Folding')
ax[0].set_xlabel('Time [s]')
ax[0].set_ylabel('$f_{rupture} \\:[pN]$')

ax[1].grid()
ax[1].legend()
ax[1].set_title('$x_{ssDNA}$')
ax[1].set_ylabel('$x_{ssDNA}$')

ax[2].grid()
ax[2].legend()
ax[2].set_title('# of nucleotides')
ax[2].set_ylabel('$N_{nucleotides}$')

plt.savefig(f'imgs/{folder}/{f_max}/f_MAX_{f_max}_Folding.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(3, figsize=(12, 20))
g = 0

for m in range(len(molecules)):
    col = colors[m]
    for i in range(len(all_molecules_u[m])):
        g += 1
        lab = f'Molecule {molecules[m]}' if i == 0 else ''
        f, f_next, x_ssDNA, N_nucleotides, t_0 = all_molecules_u[m][i][0]
        ax[0].scatter(t_0, f_next, c=col, marker=markers[m], label=lab)
        ax[1].scatter(g, x_ssDNA, c=col, marker=markers[m], label=lab)
        ax[2].scatter(g, N_nucleotides, c=col, marker=markers[m], label=lab)

ax[0].grid()
ax[0].legend(loc='best')
ax[0].set_title(f'f_MAX = {f_max} -- Unfolding')
ax[0].set_xlabel('Time [s]')
ax[0].set_ylabel('$f_{rupture} \\:[pN]$')

ax[1].grid()
ax[1].legend()
ax[1].set_title('$x_{ssDNA}$')
ax[1].set_ylabel('$x_{ssDNA}$')

ax[2].grid()
ax[2].legend()
ax[2].set_title('# of nucleotides')
ax[2].set_ylabel('$N_{nucleotides}$')

plt.savefig(f'imgs/{folder}/{f_max}/f_MAX_{f_max}_Unfolding.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Plots per single molecule

# %%
for m in range(len(molecules)):
    fig, ax = plt.subplots(3, figsize=(8, 18))
    col = colors[m]
    g = 0
    for i in range(len(all_molecules_f[m])):
        g += 1 
        lab = f'Molecule {molecules[m]}' if i == 0 else ''
        f, f_next, x_ssDNA, N_nucleotides, t_0 = all_molecules_f[m][i][0]
        ax[0].scatter(t_0, f, c=col, marker=markers[m], label=lab)
        ax[1].scatter(g, x_ssDNA, c=col, marker=markers[m], label=lab)
        ax[2].scatter(g, N_nucleotides, c=col, marker=markers[m], label=lab)
    ax[0].grid()
    ax[0].legend(loc='best')
    ax[0].set_title(f'f_MAX = {f_max} -- Unfolding')
    ax[0].set_xlabel('Time [s]')
    ax[0].set_ylabel('$f_{rupture} \\:[pN]$')

    ax[1].grid()
    ax[1].legend()
    ax[1].set_title('$x_{ssDNA}$')
    ax[1].set_ylabel('$x_{ssDNA}$')

    ax[2].grid()
    ax[2].legend()
    ax[2].set_title('# of nucleotides')
    ax[2].set_ylabel('$N_{nucleotides}$')
    plt.savefig(f'imgs/{folder}/{f_max}/f_MAX_{f_max}_Folding_Molecule{molecules[m]}.png', dpi=300, bbox_inches='tight')
    plt.show()

# %%
for m in range(len(molecules)):
    fig, ax = plt.subplots(3, figsize=(8, 18))
    col = colors[m]
    g = 0
    for i in range(len(all_molecules_u[m])):
        g += 1 
        lab = f'Molecule {molecules[m]}' if i == 0 else ''
        f, f_next, x_ssDNA, N_nucleotides, t_0 = all_molecules_u[m][i][0]
        ax[0].scatter(t_0, f, c=col, marker=markers[m], label=lab)
        ax[1].scatter(g, x_ssDNA, c=col, marker=markers[m], label=lab)
        ax[2].scatter(g, N_nucleotides, c=col, marker=markers[m], label=lab)
    ax[0].grid()
    ax[0].legend(loc='best')
    ax[0].set_title(f'f_MAX = {f_max} -- Unfolding')
    ax[0].set_xlabel('Time [s]')
    ax[0].set_ylabel('$f_{rupture} \\:[pN]$')

    ax[1].grid()
    ax[1].legend()
    ax[1].set_title('$x_{ssDNA}$')
    ax[1].set_ylabel('$x_{ssDNA}$')

    ax[2].grid()
    ax[2].legend()
    ax[2].set_title('# of nucleotides')
    ax[2].set_ylabel('$N_{nucleotides}$')
    plt.savefig(f'imgs/{folder}/{f_max}/f_MAX_{f_max}_Unfolding_Molecule{molecules[m]}.png', dpi=300, bbox_inches='tight')
    plt.show()
